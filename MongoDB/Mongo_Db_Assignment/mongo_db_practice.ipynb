# %%
import pymongo

# %%
dbConn = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
dataBase = dbConn["iNeuron"]

# %%
collection = dataBase['Addmision_details']

# %%
#copy below command and paste in terminal in same directory Mongo_DB_Assignment
mongoimport --db iNeuron --collection Addmision_details --type csv --file locations.csv --headerline
# Out:
#   Cell In[7], line 1
#     mongoimport --db iNeuron --collection Addmision_details --type csv --file locations.csv --headerline
#                      ^
# SyntaxError: invalid syntax

# %%
all_records = collection.find()

# %%
for i in all_records:
    print(i)
# Out:
# {'_id': ObjectId('638f9a669b58aacaaeff83ca'), 'Serial No': 2, 'GRE Score': 324, 'TOEFL Score': 107, 'University Rating': 4, 'SOP': 4, 'LOR': 4.5, 'CGPA': 8.87, 'Research': 1, 'Chance of Admit': 0.76}
# {'_id': ObjectId('638f9a669b58aacaaeff83cb'), 'Serial No': 3, 'GRE Score': 316, 'TOEFL Score': 104, 'University Rating': 3, 'SOP': 3, 'LOR': 3.5, 'CGPA': 8, 'Research': 1, 'Chance of Admit': 0.72}
# {'_id': ObjectId('638f9a669b58aacaaeff83cc'), 'Serial No': 4, 'GRE Score': 322, 'TOEFL Score': 110, 'University Rating': 3, 'SOP': 3.5, 'LOR': 2.5, 'CGPA': 8.67, 'Research': 1, 'Chance of Admit': 0.8}
# {'_id': ObjectId('638f9a669b58aacaaeff83cd'), 'Serial No': 5, 'GRE Score': 314, 'TOEFL Score': 103, 'University Rating': 2, 'SOP': 2, 'LOR': 3, 'CGPA': 8.21, 'Research': 0, 'Chance of Admit': 0.65}
# ...

# %%
import pandas as pd

# %%
import pymongo

# %%
data = pd.read_csv('https://raw.githubusercontent.com/vigneshk/Admission-Dataset/master/Admission.csv')
dbConn = pymongo.MongoClient("mongodb://localhost:27017/")
db = dbConn['iNeuron']
collection = db['Addmision_details']
data.reset_index(inplace=True)
data_dict = data.to_dict("records")
# Insert collection
collection.insert_many(data_dict)

# %%
all_records = collection.find()

# %%
for i in all_records:
    print(i)
# Out:
# {'_id': ObjectId('6390901f56137f422139b0f2'), 'index': 0, 'Serial No.': 1, 'GRE Score': 337, 'TOEFL Score': 118, 'University Rating': 4, 'SOP': 4.5, 'LOR ': 4.5, 'CGPA': 9.65, 'Research': 1, 'Chance of Admit ': 0.92}
# {'_id': ObjectId('6390901f56137f422139b0f3'), 'index': 1, 'Serial No.': 2, 'GRE Score': 324, 'TOEFL Score': 107, 'University Rating': 4, 'SOP': 4.0, 'LOR ': 4.5, 'CGPA': 8.87, 'Research': 1, 'Chance of Admit ': 0.76}
# {'_id': ObjectId('6390901f56137f422139b0f4'), 'index': 2, 'Serial No.': 3, 'GRE Score': 316, 'TOEFL Score': 104, 'University Rating': 3, 'SOP': 3.0, 'LOR ': 3.5, 'CGPA': 8.0, 'Research': 1, 'Chance of Admit ': 0.72}
# {'_id': ObjectId('6390901f56137f422139b0f5'), 'index': 3, 'Serial No.': 4, 'GRE Score': 322, 'TOEFL Score': 110, 'University Rating': 3, 'SOP': 3.5, 'LOR ': 2.5, 'CGPA': 8.67, 'Research': 1, 'Chance of Admit ': 0.8}
# ...
