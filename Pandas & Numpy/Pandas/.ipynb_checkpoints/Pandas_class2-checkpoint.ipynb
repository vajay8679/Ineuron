# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html') #only show tables tab data

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','Tm']]
# Out:
#     Age   Tm
# 0    24  NYK
# 1    20  MEM
# 2    21  OKC
# 3    28  MIN
# 4    29  TOT
# ..   ..  ...
# 670  26  TOT
# 671  26  MIN
# 672  26  BRK
# 673  22  CHO
# 674  25  BOS
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv',index=False) #it won't take index in first column

# %%
ls
# Out:
#  addresses.csv
#  contacts.csv
#  holiday_schedules.csv
#  locations.csv
# 'LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx'
# 'LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx'
# 'LUSID Excel - Manage instruments with economic definitions.xlsx'
# 'LUSID Excel - Manage Orders.xlsx'
# 'LUSID Excel - Manage your investment strategies.xlsx'
# 'LUSID Excel - Setting up your IBOR.xlsx'
# 'LUSID Excel - Setting up your market data.xlsx'
#  mail_addresses.csv
#  NBA.csv
#  organizations.csv
#  Pandas_class1.ipynb
#  Pandas_class2.ipynb
#  phones.csv
#  programs.csv
#  regular_schedules.csv
#  sample1.csv
#  sample2.csv
#  sample.csv
#  services.csv
#  taxonomy.csv

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
l
# Out:
# [                Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
#  0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
#  1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
#  2            S Aravind  2015-2015    1    -   0     -    -      -    0.00   -
#  3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   60.00   -
#  4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
#  ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
#  97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
#  98   Washington Sundar  2017-2023   35   14   4   107   50  10.70  152.85   -
#  99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  175.76   3
#  100           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
#  101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#       50  0
#  0     -  -
#  1     -  -
#  2     -  -
#  3     -  -
#  4     -  -
#  ..   .. ..
#  97    -  -
#  98    1  4
#  99   13  3
#  100   -  -
#  101   8  1
#
#  [102 rows x 12 columns]]

# %%
len(l)
# Out:
# 1

# %%
l[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
# 2            S Aravind  2015-2015    1    -   0     -    -      -    0.00   -
# 3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   60.00   -
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
# ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70  152.85   -
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  175.76   3
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#      50  0
# 0     -  -
# 1     -  -
# 2     -  -
# 3     -  -
# 4     -  -
# ..   .. ..
# 97    -  -
# 98    1  4
# 99   13  3
# 100   -  -
# 101   8  1
#
# [102 rows x 12 columns]

# %%
l[0].to_csv('cricket.csv',index=False)

# %%
d = """
{"name" : "Ajay kumar",
 "email" : "vajay8679@gmail.com",
  "tech" : ["Python","Pyspark","SQL","Pandas","Hive"],
  "Platform" : ["edyoda","Ineuron","Upgrad"]
}
"""

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Ajay kumar',
#  'email': 'vajay8679@gmail.com',
#  'tech': ['Python', 'Pyspark', 'SQL', 'Pandas', 'Hive'],
#  'Platform': ['edyoda', 'Ineuron', 'Upgrad']}

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# 'Ajay kumar'

# %%
pd.DataFrame(result['tech'])
# Out:
#          0
# 0   Python
# 1  Pyspark
# 2      SQL
# 3   Pandas
# 4     Hive

# %%
result['tech']
# Out:
# ['Python', 'Pyspark', 'SQL', 'Pandas', 'Hive']

# %%
pd.DataFrame(result) #same length of list - tech,platform otherwise it wont work
# Out:
#          name                email     tech Platform
# 0  Ajay kumar  vajay8679@gmail.com   Python   edyoda
# 1  Ajay kumar  vajay8679@gmail.com  Pyspark  Ineuron
# 2  Ajay kumar  vajay8679@gmail.com      SQL   Upgrad

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
d["data"]
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d["data"]) #bcz of size is not equal of list inside
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [73], line 1
# ----> 1 pd.DataFrame(d["data"])
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
d1 = d["data"]

# %%
del d1["diagnosticTroubleCodeData"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d["data"]) #bcz of size is not equal of list inside
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/54226  1816552876
# 1     https://github.com/pandas-dev/pandas/pull/54225  1816520062
# 2     https://github.com/pandas-dev/pandas/pull/54224  1816512127
# 3     https://github.com/pandas-dev/pandas/pull/54223  1816498433
# 4     https://github.com/pandas-dev/pandas/pull/54222  1816496485
# 5     https://github.com/pandas-dev/pandas/pull/54221  1816492139
# 6     https://github.com/pandas-dev/pandas/pull/54220  1816445866
# 7     https://github.com/pandas-dev/pandas/pull/54219  1816415144
# 8     https://github.com/pandas-dev/pandas/pull/54218  1816253128
# 9     https://github.com/pandas-dev/pandas/pull/54217  1816206681
# 10    https://github.com/pandas-dev/pandas/pull/54216  1815855321
# 11    https://github.com/pandas-dev/pandas/pull/54214  1814840772
# 12  https://github.com/pandas-dev/pandas/issues/54212  1814501132
# 13    https://github.com/pandas-dev/pandas/pull/54209  1814325893
# 14  https://github.com/pandas-dev/pandas/issues/54206  1813812535
# 15  https://github.com/pandas-dev/pandas/issues/54204  1813437622
# 16  https://github.com/pandas-dev/pandas/issues/54203  1813359655
# 17    https://github.com/pandas-dev/pandas/pull/54200  1812855663
# 18  https://github.com/pandas-dev/pandas/issues/54199  1812736733
# 19    https://github.com/pandas-dev/pandas/pull/54198  1812706435
# 20  https://github.com/pandas-dev/pandas/issues/54195  1812112194
# 21  https://github.com/pandas-dev/pandas/issues/54194  1812052615
# 22  https://github.com/pandas-dev/pandas/issues/54193  1812036176
# 23  https://github.com/pandas-dev/pandas/issues/54192  1811897004
# 24  https://github.com/pandas-dev/pandas/issues/54191  1811847359
# 25  https://github.com/pandas-dev/pandas/issues/54190  1811692387
# 26    https://github.com/pandas-dev/pandas/pull/54188  1811292625
# 27  https://github.com/pandas-dev/pandas/issues/54187  1811119103
# 28  https://github.com/pandas-dev/pandas/issues/54178  1808994132
# 29    https://github.com/pandas-dev/pandas/pull/54177  1808993971
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85WIz4E   54226
# 1   PR_kwDOAA0YD85WItdj   54225
# 2   PR_kwDOAA0YD85WIr0n   54224
# 3   PR_kwDOAA0YD85WIot5   54223
# 4   PR_kwDOAA0YD85WIoRD   54222
# 5   PR_kwDOAA0YD85WInR3   54221
# 6   PR_kwDOAA0YD85WIdeM   54220
# 7   PR_kwDOAA0YD85WIW2J   54219
# 8   PR_kwDOAA0YD85WHz-S   54218
# 9   PR_kwDOAA0YD85WHpkR   54217
# 10  PR_kwDOAA0YD85WGdoi   54216
# 11  PR_kwDOAA0YD85WDD04   54214
# 12   I_kwDOAA0YD85sJxcM   54212
# 13  PR_kwDOAA0YD85WBSTu   54209
# 14   I_kwDOAA0YD85sHJU3   54206
# 15   I_kwDOAA0YD85sFty2   54204
# 16   I_kwDOAA0YD85sFawn   54203
# 17  PR_kwDOAA0YD85V8O2-   54200
# 18   I_kwDOAA0YD85sDCrd   54199
# 19  PR_kwDOAA0YD85V7uJj   54198
# 20   I_kwDOAA0YD85sAqNC   54195
# 21   I_kwDOAA0YD85sAbqH   54194
# 22   I_kwDOAA0YD85sAXpQ   54193
# 23   I_kwDOAA0YD85r_1qs   54192
# 24   I_kwDOAA0YD85r_pi_   54191
# 25   I_kwDOAA0YD85r_Dtj   54190
# 26  PR_kwDOAA0YD85V23Mf   54188
# 27   I_kwDOAA0YD85r83v_   54187
# 28   I_kwDOAA0YD85r0w9U   54178
# 29  PR_kwDOAA0YD85VvGer   54177
#
#                                                 title  ... closed_at  \
# 0                     DEPR: idxmin/idxmax with all-NA  ...       NaT
# 1   CLN/ASV: remove downcast param (deprecated) fr...  ...       NaT
# 2        PERF: DataFrame.transpose for pyarrow-backed  ...       NaT
# 3                             PERF: ArrowDtype.__eq__  ...       NaT
# 4                       CI/TST: Address some warnings  ...       NaT
# 5   CLN/ASV: DataFrame.applymap (deprecated) -> Da...  ...       NaT
# 6                     DOC: Simplify contributing into  ...       NaT
# 7                    DEPR: Series.argsort NA behavior  ...       NaT
# 8                     CI: Try out pre-commit.ci again  ...       NaT
# 9                   DOC: Fixing EX01 - Added examples  ...       NaT
# 10  DOC: Removed InvalidComparison and LossySetIte...  ...       NaT
# 11  FIX: query() and isin() fail on period type co...  ...       NaT
# 12  BUG: Doc build fails locally due to `rstjinja`...  ...       NaT
# 13  TST: Use numpy random generator for testing data   ...       NaT
# 14  BUG: Grouped rank incorrect behaviour with nul...  ...       NaT
# 15    BUG: Scatter plot has a hardcoded default value  ...       NaT
# 16  BUG: `AttributeError` when `rolling.agg` use `...  ...       NaT
# 17  CI: Bump pandas-gbq to one that doesn't pin py...  ...       NaT
# 18  BUG: `.query()` and `isin()` fail on period ty...  ...       NaT
# 19             POC: pass date_unit to values_for_json  ...       NaT
# 20                                              BUG:   ...       NaT
# 21  BUG: in a level of `MultiIndex` tz info is los...  ...       NaT
# 22  BUG: pd.Series.describe ignores include, exclu...  ...       NaT
# 23  BUG: pd.to_latex does not escape percentage si...  ...       NaT
# 24  BUG: `convert_dtypes(dtype_backend="pyarrow")`...  ...       NaT
# 25  BUG: `testing.assert_frame_equal` unhelpful er...  ...       NaT
# 26             Fix deprecation warning on Python 3.12  ...       NaT
# 27  ENH: allow `ewm()` to use a DatetimeIndex if `...  ...       NaT
# 28  BUILD: `ValueError` raised when importing pand...  ...       NaT
# 29                                     Fix for #54167  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0              MEMBER                NaN    0.0
# 1         CONTRIBUTOR                NaN    0.0
# 2         CONTRIBUTOR                NaN    0.0
# 3         CONTRIBUTOR                NaN    0.0
# 4              MEMBER                NaN    0.0
# 5         CONTRIBUTOR                NaN    0.0
# 6              MEMBER                NaN    0.0
# 7              MEMBER                NaN    0.0
# 8              MEMBER                NaN    0.0
# 9              MEMBER                NaN    0.0
# 10             MEMBER                NaN    0.0
# 11        CONTRIBUTOR                NaN    1.0
# 12               NONE                NaN    NaN
# 13             MEMBER                NaN    0.0
# 14        CONTRIBUTOR                NaN    NaN
# 15               NONE                NaN    NaN
# 16               NONE                NaN    NaN
# 17             MEMBER                NaN    0.0
# 18               NONE                NaN    NaN
# 19             MEMBER                NaN    0.0
# 20               NONE                NaN    NaN
# 21               NONE                NaN    NaN
# 22               NONE                NaN    NaN
# 23               NONE                NaN    NaN
# 24               NONE                NaN    NaN
# 25               NONE                NaN    NaN
# 26        CONTRIBUTOR                NaN    0.0
# 27        CONTRIBUTOR                NaN    NaN
# 28        CONTRIBUTOR                NaN    NaN
# 29               NONE                NaN    0.0
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   - [x] closes #51276 (Replace xxxx with the Git...
# 1                                                None
# 2   - [x] [Tests added and passed](https://pandas....
# 3   Micro-perf improvement:\r\n\r\n```\r\nimport p...
# 4                                                None
# 5                                                None
# 6   * Reduced some preamble\r\n* Updated some link...
# 7   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 8      Will need to enable the pre-commit Github app
# 9   - [x] All [code checks passed](https://pandas....
# 10  - [x] All [code checks passed](https://pandas....
# 11  - [X] closes #54199\r\n- [ ] [Tests added and ...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  This PR diff is large, but essentially it enab...
# 14  ### Pandas version checks\r\n\r\n- [X] I have ...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  @WillAyd this isn't working (or even compiling...
# 20  ### Pandas version checks\n\n- [X] I have chec...
# 21  ### Pandas version checks\r\n\r\n- [X] I have ...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ### Pandas version checks\r\n\r\n- [X] I have ...
# 25  ### Pandas version checks\r\n\r\n- [X] I have ...
# 26  `Constant.n` is now deprecated for removal in ...
# 27  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 28  ### Installation check\n\n- [X] I have read th...
# 29  - [x] closes #54167\r\n- [x] All [code checks ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54226',
#   'id': 1816552876,
#   'node_id': 'PR_kwDOAA0YD85WIz4E',
#   'number': 54226,
#   'title': 'DEPR: idxmin/idxmax with all-NA',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-22T02:29:07Z',
#   'updated_at': '2023-07-22T02:29:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54226',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54226',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54226.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54226.patch',
#    'merged_at': None},
#   'body': "- [x] closes #51276 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAs discussed in last week's dev call.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54225',
#   'id': 1816520062,
#   'node_id': 'PR_kwDOAA0YD85WItdj',
#   'number': 54225,
#   'title': 'CLN/ASV: remove downcast param (deprecated) from frame_methods.Interpolate',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T01:01:37Z',
#   'updated_at': '2023-07-22T01:01:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54225',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54225',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54225.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54225.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54224',
#   'id': 1816512127,
#   'node_id': 'PR_kwDOAA0YD85WIr0n',
#   'number': 54224,
#   'title': 'PERF: DataFrame.transpose for pyarrow-backed',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T00:34:35Z',
#   'updated_at': '2023-07-22T02:28:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54224',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54224',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54224.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54224.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.1.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nSimilar to #52836, but for pyarrow-backed frames. \r\n\r\n```\r\nimport pandas as pd\r\nimport pyarrow as pa\r\nimport numpy as np\r\n\r\nvalues = np.random.randn(1000, 1000)\r\ndf = pd.DataFrame(values, dtype=pd.ArrowDtype(pa.float64()))\r\n\r\n%timeit timeit df.T\r\n\r\n# 346 ms ± 67.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)    -> main\r\n# 42.5 ms ± 2.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each) -> PR\r\n```\r\n\r\nRenamed the masked implementation from `homogenous` -> `homogeneous`. Both may be valid(?), but `homogeneous` is used elsewhere.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54223',
#   'id': 1816498433,
#   'node_id': 'PR_kwDOAA0YD85WIot5',
#   'number': 54223,
#   'title': 'PERF: ArrowDtype.__eq__',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T00:12:28Z',
#   'updated_at': '2023-07-22T00:13:58Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54223',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54223',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54223.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54223.patch',
#    'merged_at': None},
#   'body': 'Micro-perf improvement:\r\n\r\n```\r\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\na = pd.ArrowDtype(pa.float64())\r\nb = pd.ArrowDtype(pa.float64())\r\n\r\n%timeit a == b\r\n\r\n# 2.86 µs ± 214 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)   -> main\r\n# 473 ns ± 15.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each) -> PR\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54222',
#   'id': 1816496485,
#   'node_id': 'PR_kwDOAA0YD85WIoRD',
#   'number': 54222,
#   'title': 'CI/TST: Address some warnings',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-22T00:10:14Z',
#   'updated_at': '2023-07-22T00:10:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54222',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54222',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54222.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54222.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54221',
#   'id': 1816492139,
#   'node_id': 'PR_kwDOAA0YD85WInR3',
#   'number': 54221,
#   'title': 'CLN/ASV: DataFrame.applymap (deprecated) -> DataFrame.map',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T00:05:28Z',
#   'updated_at': '2023-07-22T00:14:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54221',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54221',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54221.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54221.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54220',
#   'id': 1816445866,
#   'node_id': 'PR_kwDOAA0YD85WIdeM',
#   'number': 54220,
#   'title': 'DOC: Simplify contributing into',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-21T22:30:48Z',
#   'updated_at': '2023-07-21T22:30:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54220',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54220',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54220.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54220.patch',
#    'merged_at': None},
#   'body': '* Reduced some preamble\r\n* Updated some links\r\n* Use `code-block:: shell` where appropriate',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54219',
#   'id': 1816415144,
#   'node_id': 'PR_kwDOAA0YD85WIW2J',
#   'number': 54219,
#   'title': 'DEPR: Series.argsort NA behavior',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-21T21:44:26Z',
#   'updated_at': '2023-07-21T21:44:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54219',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54219',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54219.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54219.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nSeries.argsort has NA behavior different from EA.argsort/nargsort (xref #43840) that seems really useless to me.  This deprecates that behavior so in the future we can just pass through to the EA.\r\n\r\nWe _could_ expose the EA's na_position keyword, but let's wait on that until someone asks for it.  AFAIK this isn't really used.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54218',
#   'id': 1816253128,
#   'node_id': 'PR_kwDOAA0YD85WHz-S',
#   'number': 54218,
#   'title': 'CI: Try out pre-commit.ci again',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Code%20Style',
#     'name': 'Code Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-21T18:52:41Z',
#   'updated_at': '2023-07-21T18:52:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54218',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54218',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54218.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54218.patch',
#    'merged_at': None},
#   'body': 'Will need to enable the pre-commit Github app ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54217',
#   'id': 1816206681,
#   'node_id': 'PR_kwDOAA0YD85WHpkR',
#   'number': 54217,
#   'title': 'DOC: Fixing EX01 - Added examples',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
#    'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#    'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#    'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#    'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-21T18:19:11Z',
#   'updated_at': '2023-07-21T18:19:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54217',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54217',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54217.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54217.patch',
#    'merged_at': None},
#   'body': '- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nTowards https://github.com/pandas-dev/pandas/issues/37875\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54216',
#   'id': 1815855321,
#   'node_id': 'PR_kwDOAA0YD85WGdoi',
#   'number': 54216,
#   'title': 'DOC: Removed InvalidComparison\xa0and\xa0LossySetItemError from docs',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
#    'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#    'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#    'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#    'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2023-07-21T13:54:42Z',
#   'updated_at': '2023-07-21T17:47:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54216',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54216',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54216.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54216.patch',
#    'merged_at': None},
#   'body': '- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nTowards https://github.com/pandas-dev/pandas/issues/37875\r\n\r\nhttps://github.com/pandas-dev/pandas/pull/48088\r\nhttps://github.com/pandas-dev/pandas/pull/48687\r\n\r\n@jorisvandenbossche @mroeschke : Could you comment if this is OK please? thanks.\r\nSuggested by @MarcoGorelli',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54214',
#   'id': 1814840772,
#   'node_id': 'PR_kwDOAA0YD85WDD04',
#   'number': 54214,
#   'title': 'FIX: query() and isin() fail on period type column',
#   'user': {'login': 'dannyi96',
# ...
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54188',
#   'id': 1811292625,
#   'node_id': 'PR_kwDOAA0YD85V23Mf',
#   'number': 54188,
#   'title': 'Fix deprecation warning on Python 3.12',
#   'user': {'login': 'QuLogic',
#    'id': 302469,
#    'node_id': 'MDQ6VXNlcjMwMjQ2OQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/302469?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/QuLogic',
#    'html_url': 'https://github.com/QuLogic',
#    'followers_url': 'https://api.github.com/users/QuLogic/followers',
#    'following_url': 'https://api.github.com/users/QuLogic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/QuLogic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/QuLogic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/QuLogic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/QuLogic/orgs',
#    'repos_url': 'https://api.github.com/users/QuLogic/repos',
#    'events_url': 'https://api.github.com/users/QuLogic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/QuLogic/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1631985267,
#     'node_id': 'MDU6TGFiZWwxNjMxOTg1MjY3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/expressions',
#     'name': 'expressions',
#     'color': 'f3afff',
#     'default': False,
#     'description': 'pd.eval, query'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-07-19T07:01:05Z',
#   'updated_at': '2023-07-19T17:40:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54188',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54188',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54188.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54188.patch',
#    'merged_at': None},
#   'body': '`Constant.n` is now deprecated for removal in 3.14; it appears that `Constant.value` has existed since at least 3.9.\r\n\r\n- [n/a] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [n/a] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54187',
#   'id': 1811119103,
#   'node_id': 'I_kwDOAA0YD85r83v_',
#   'number': 54187,
#   'title': "ENH: allow `ewm()` to use a DatetimeIndex if `times` isn't provided",
#   'user': {'login': 'gsiano',
#    'id': 355612,
#    'node_id': 'MDQ6VXNlcjM1NTYxMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/355612?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gsiano',
#    'html_url': 'https://github.com/gsiano',
#    'followers_url': 'https://api.github.com/users/gsiano/followers',
#    'following_url': 'https://api.github.com/users/gsiano/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gsiano/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gsiano/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gsiano/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gsiano/orgs',
#    'repos_url': 'https://api.github.com/users/gsiano/repos',
#    'events_url': 'https://api.github.com/users/gsiano/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gsiano/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-19T04:27:33Z',
#   'updated_at': '2023-07-19T04:34:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Feature Type\r\n\r\n- [ ] Adding new functionality to pandas\r\n\r\n- [X] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\n`rolling()` allows passing a timedelta window when the DataFrame has a `DatetimeIndex`. `ewm()` requires passing the `times` parameter when using a timedelta halflife with a `DatetimeIndex`. I think `ewm()` should default to using the index as `times` if it is a `DatetimeIndex` and `halflife` is a timedelta. This way it would be more similar to the `rolling()` behavior, and in my experience I\'ve only ever seen `df.index` passed as the `times` argument. It seems counterintuitive to me to have to explicitly pass the index to `ewm()` when working with times and timedeltas.\r\n\r\n### Feature Description\r\n\r\nIf the `halflife` parameter to `ewm()` is a timedelta and `times` is not explicitly passed, use the index if it is a `DatetimeIndex`.\r\n\r\nhttps://github.com/pandas-dev/pandas/pull/54181\r\n\r\n### Alternative Solutions\r\n\r\nThe alternative would be to keep the existing behavior.\r\n\r\n### Additional Context\r\n\r\nCurrent:\r\n```\r\n>>> now = pd.Timestamp.now()\r\n>>> idx = [now + pd.Timedelta(seconds=i) for i in range(1, 4)]\r\n>>> df = pd.DataFrame({\'a\': [1,2,3]}, index=idx)\r\n>>> df.ewm(halflife=pd.Timedelta(seconds=1)).mean()\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/home/gsiano/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 11743, in ewm\r\n    return ExponentialMovingWindow(\r\n  File "/home/gsiano/.local/lib/python3.10/site-packages/pandas/core/window/ewm.py", line 386, in __init__\r\n    raise ValueError(\r\nValueError: halflife can only be a timedelta convertible argument if times is not None.\r\n>>> df.ewm(halflife=pd.Timedelta(seconds=1), times=df.index).mean()\r\n                                   a\r\n2023-07-18 10:45:18.007264  1.000000\r\n2023-07-18 10:45:19.007264  1.666667\r\n2023-07-18 10:45:20.007264  2.428571\r\n>>> \r\n```\r\n\r\nProposed:\r\n```\r\n>>> now = pd.Timestamp.now()\r\n>>> idx = [now + pd.Timedelta(seconds=i) for i in range(1, 4)]\r\n>>> df = pd.DataFrame({\'a\': [1,2,3]}, index=idx)\r\n>>> df.ewm(halflife=pd.Timedelta(seconds=1)).mean()\r\n                                   a\r\n2023-07-18 10:46:46.589891  1.000000\r\n2023-07-18 10:46:47.589891  1.666667\r\n2023-07-18 10:46:48.589891  2.428571\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54178',
#   'id': 1808994132,
#   'node_id': 'I_kwDOAA0YD85r0w9U',
#   'number': 54178,
#   'title': 'BUILD: `ValueError` raised when importing pandas due to `numpy.ndarray` size change',
#   'user': {'login': 'luke396',
#    'id': 77875500,
#    'node_id': 'MDQ6VXNlcjc3ODc1NTAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77875500?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luke396',
#    'html_url': 'https://github.com/luke396',
#    'followers_url': 'https://api.github.com/users/luke396/followers',
#    'following_url': 'https://api.github.com/users/luke396/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/luke396/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/luke396/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/luke396/subscriptions',
#    'organizations_url': 'https://api.github.com/users/luke396/orgs',
#    'repos_url': 'https://api.github.com/users/luke396/repos',
#    'events_url': 'https://api.github.com/users/luke396/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/luke396/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-07-18T03:11:27Z',
#   'updated_at': '2023-07-18T19:53:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Installation check\n\n- [X] I have read the [installation guide](https://pandas.pydata.org/pandas-docs/stable/getting_started/install.html#installing-pandas).\n\n\n### Platform\n\nLinux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.31\n\n### Installation Method\n\npip install\n\n### pandas Version\n\n2.1.0.dev0+1210.gaa4922a96b\n\n### Python Version\n\n3.10.12\n\n### Installation Logs\n\nI followed the instructions provided at https://pandas.pydata.org/docs/dev/development/contributing_environment.html and successfully installed pandas using `mamba` with the command `python -m pip install -ve . --no-build-isolation --config-settings editable-verbose=true`.\r\n\r\nHowever, when attempting to import pandas using either `pytest pandas` or `import pandas`, I encountered the following error: `ValueError: numpy.ndarray size changed, which may indicate binary incompatibility. Expected 96 from C header, but got 88 from PyObject`.\r\n\r\nI found a related issue at https://github.com/pandas-dev/pandas/issues/49683, where it was suggested to use `pip install oldest-supported-numpy` maybe resolve the problem. However, this command installs numpy-1.21.6 and did not work for me.\r\n\r\nFortunately, I received help from @Dr-Irv on Slack, who recommended using the following command: `mamba install numpy=1.23.2 -c conda-forge`. This solution worked for me.\r\n\r\nI spent a significant amount of time attempting various approaches without success. As a result, I am documenting this solution to assist anyone who may encounter a similar problem in the future, thereby saving them time and effort.\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54177',
#   'id': 1808993971,
#   'node_id': 'PR_kwDOAA0YD85VvGer',
#   'number': 54177,
#   'title': 'Fix for #54167',
#   'user': {'login': 'harikirank',
#    'id': 58730670,
#    'node_id': 'MDQ6VXNlcjU4NzMwNjcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58730670?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harikirank',
#    'html_url': 'https://github.com/harikirank',
#    'followers_url': 'https://api.github.com/users/harikirank/followers',
#    'following_url': 'https://api.github.com/users/harikirank/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/harikirank/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/harikirank/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/harikirank/subscriptions',
#    'organizations_url': 'https://api.github.com/users/harikirank/orgs',
#    'repos_url': 'https://api.github.com/users/harikirank/repos',
#    'events_url': 'https://api.github.com/users/harikirank/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/harikirank/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-07-18T03:11:14Z',
#   'updated_at': '2023-07-19T17:08:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54177',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54177',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54177.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54177.patch',
#    'merged_at': None},
#   'body': '- [x] closes #54167\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/54226',
#  'id': 1816552876,
#  'node_id': 'PR_kwDOAA0YD85WIz4E',
#  'number': 54226,
#  'title': 'DEPR: idxmin/idxmax with all-NA',
#  'user': {'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
#   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [],
#  'state': 'open',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2023-07-22T02:29:07Z',
#  'updated_at': '2023-07-22T02:29:07Z',
#  'closed_at': None,
#  'author_association': 'MEMBER',
#  'active_lock_reason': None,
#  'draft': False,
#  'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54226',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54226',
#   'diff_url': 'https://github.com/pandas-dev/pandas/pull/54226.diff',
#   'patch_url': 'https://github.com/pandas-dev/pandas/pull/54226.patch',
#   'merged_at': None},
#  'body': "- [x] closes #51276 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAs discussed in last week's dev call.",
#  'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/timeline',
#  'performed_via_github_app': None,
#  'state_reason': None}

# %%
data1[0]["user"]
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data1[0]["user"]["id"]
# Out:
# 8078968

# %%
for i in range(len(data1)):
    print(data1[i]["user"]["id"])
# Out:
# 8078968
# 8519523
# 8519523
# 8519523
# 10647082
# 8519523
# 10647082
# 8078968
# 10647082
# 11835246
# 11835246
# 15380498
# 25615622
# 10647082
# 9914734
# 1765698
# 9063883
# 47963215
# 4443482
# 8078968
# 2798595
# 56914820
# 31903015
# 4571777
# 39696536
# 39696536
# 302469
# 355612
# 77875500
# 58730670

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54226',
#   'id': 1816552876,
#   'node_id': 'PR_kwDOAA0YD85WIz4E',
#   'number': 54226,
#   'title': 'DEPR: idxmin/idxmax with all-NA',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-22T02:29:07Z',
#   'updated_at': '2023-07-22T02:29:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54226',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54226',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54226.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54226.patch',
#    'merged_at': None},
#   'body': "- [x] closes #51276 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAs discussed in last week's dev call.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54226/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54225',
#   'id': 1816520062,
#   'node_id': 'PR_kwDOAA0YD85WItdj',
#   'number': 54225,
#   'title': 'CLN/ASV: remove downcast param (deprecated) from frame_methods.Interpolate',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T01:01:37Z',
#   'updated_at': '2023-07-22T01:01:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54225',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54225',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54225.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54225.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54225/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54224',
#   'id': 1816512127,
#   'node_id': 'PR_kwDOAA0YD85WIr0n',
#   'number': 54224,
#   'title': 'PERF: DataFrame.transpose for pyarrow-backed',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T00:34:35Z',
#   'updated_at': '2023-07-22T02:28:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54224',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54224',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54224.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54224.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.1.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nSimilar to #52836, but for pyarrow-backed frames. \r\n\r\n```\r\nimport pandas as pd\r\nimport pyarrow as pa\r\nimport numpy as np\r\n\r\nvalues = np.random.randn(1000, 1000)\r\ndf = pd.DataFrame(values, dtype=pd.ArrowDtype(pa.float64()))\r\n\r\n%timeit timeit df.T\r\n\r\n# 346 ms ± 67.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)    -> main\r\n# 42.5 ms ± 2.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each) -> PR\r\n```\r\n\r\nRenamed the masked implementation from `homogenous` -> `homogeneous`. Both may be valid(?), but `homogeneous` is used elsewhere.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54224/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54223',
#   'id': 1816498433,
#   'node_id': 'PR_kwDOAA0YD85WIot5',
#   'number': 54223,
#   'title': 'PERF: ArrowDtype.__eq__',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T00:12:28Z',
#   'updated_at': '2023-07-22T00:13:58Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54223',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54223',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54223.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54223.patch',
#    'merged_at': None},
#   'body': 'Micro-perf improvement:\r\n\r\n```\r\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\na = pd.ArrowDtype(pa.float64())\r\nb = pd.ArrowDtype(pa.float64())\r\n\r\n%timeit a == b\r\n\r\n# 2.86 µs ± 214 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)   -> main\r\n# 473 ns ± 15.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each) -> PR\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54223/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54222',
#   'id': 1816496485,
#   'node_id': 'PR_kwDOAA0YD85WIoRD',
#   'number': 54222,
#   'title': 'CI/TST: Address some warnings',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-22T00:10:14Z',
#   'updated_at': '2023-07-22T00:10:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54222',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54222',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54222.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54222.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54222/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54221',
#   'id': 1816492139,
#   'node_id': 'PR_kwDOAA0YD85WInR3',
#   'number': 54221,
#   'title': 'CLN/ASV: DataFrame.applymap (deprecated) -> DataFrame.map',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-22T00:05:28Z',
#   'updated_at': '2023-07-22T00:14:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54221',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54221',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54221.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54221.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54221/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54220',
#   'id': 1816445866,
#   'node_id': 'PR_kwDOAA0YD85WIdeM',
#   'number': 54220,
#   'title': 'DOC: Simplify contributing into',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-21T22:30:48Z',
#   'updated_at': '2023-07-21T22:30:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54220',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54220',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54220.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54220.patch',
#    'merged_at': None},
#   'body': '* Reduced some preamble\r\n* Updated some links\r\n* Use `code-block:: shell` where appropriate',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54220/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54219',
#   'id': 1816415144,
#   'node_id': 'PR_kwDOAA0YD85WIW2J',
#   'number': 54219,
#   'title': 'DEPR: Series.argsort NA behavior',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-21T21:44:26Z',
#   'updated_at': '2023-07-21T21:44:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54219',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54219',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54219.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54219.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nSeries.argsort has NA behavior different from EA.argsort/nargsort (xref #43840) that seems really useless to me.  This deprecates that behavior so in the future we can just pass through to the EA.\r\n\r\nWe _could_ expose the EA's na_position keyword, but let's wait on that until someone asks for it.  AFAIK this isn't really used.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54219/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54218',
#   'id': 1816253128,
#   'node_id': 'PR_kwDOAA0YD85WHz-S',
#   'number': 54218,
#   'title': 'CI: Try out pre-commit.ci again',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Code%20Style',
#     'name': 'Code Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-21T18:52:41Z',
#   'updated_at': '2023-07-21T18:52:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54218',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54218',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54218.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54218.patch',
#    'merged_at': None},
#   'body': 'Will need to enable the pre-commit Github app ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54218/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54217',
#   'id': 1816206681,
#   'node_id': 'PR_kwDOAA0YD85WHpkR',
#   'number': 54217,
#   'title': 'DOC: Fixing EX01 - Added examples',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
#    'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#    'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#    'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#    'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-07-21T18:19:11Z',
#   'updated_at': '2023-07-21T18:19:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54217',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54217',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54217.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54217.patch',
#    'merged_at': None},
#   'body': '- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nTowards https://github.com/pandas-dev/pandas/issues/37875\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54217/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54216',
#   'id': 1815855321,
#   'node_id': 'PR_kwDOAA0YD85WGdoi',
#   'number': 54216,
#   'title': 'DOC: Removed InvalidComparison\xa0and\xa0LossySetItemError from docs',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
#    'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#    'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#    'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#    'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 37,
#    'closed_issues': 1012,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-07-22T01:01:37Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2023-07-21T13:54:42Z',
#   'updated_at': '2023-07-21T17:47:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54216',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54216',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54216.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54216.patch',
#    'merged_at': None},
#   'body': '- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nTowards https://github.com/pandas-dev/pandas/issues/37875\r\n\r\nhttps://github.com/pandas-dev/pandas/pull/48088\r\nhttps://github.com/pandas-dev/pandas/pull/48687\r\n\r\n@jorisvandenbossche @mroeschke : Could you comment if this is OK please? thanks.\r\nSuggested by @MarcoGorelli',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54216/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54214/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54214',
#   'id': 1814840772,
#   'node_id': 'PR_kwDOAA0YD85WDD04',
#   'number': 54214,
#   'title': 'FIX: query() and isin() fail on period type column',
#   'user': {'login': 'dannyi96',
# ...
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54188',
#   'id': 1811292625,
#   'node_id': 'PR_kwDOAA0YD85V23Mf',
#   'number': 54188,
#   'title': 'Fix deprecation warning on Python 3.12',
#   'user': {'login': 'QuLogic',
#    'id': 302469,
#    'node_id': 'MDQ6VXNlcjMwMjQ2OQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/302469?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/QuLogic',
#    'html_url': 'https://github.com/QuLogic',
#    'followers_url': 'https://api.github.com/users/QuLogic/followers',
#    'following_url': 'https://api.github.com/users/QuLogic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/QuLogic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/QuLogic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/QuLogic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/QuLogic/orgs',
#    'repos_url': 'https://api.github.com/users/QuLogic/repos',
#    'events_url': 'https://api.github.com/users/QuLogic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/QuLogic/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1631985267,
#     'node_id': 'MDU6TGFiZWwxNjMxOTg1MjY3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/expressions',
#     'name': 'expressions',
#     'color': 'f3afff',
#     'default': False,
#     'description': 'pd.eval, query'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-07-19T07:01:05Z',
#   'updated_at': '2023-07-19T17:40:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54188',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54188',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54188.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54188.patch',
#    'merged_at': None},
#   'body': '`Constant.n` is now deprecated for removal in 3.14; it appears that `Constant.value` has existed since at least 3.9.\r\n\r\n- [n/a] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [n/a] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54188/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54187',
#   'id': 1811119103,
#   'node_id': 'I_kwDOAA0YD85r83v_',
#   'number': 54187,
#   'title': "ENH: allow `ewm()` to use a DatetimeIndex if `times` isn't provided",
#   'user': {'login': 'gsiano',
#    'id': 355612,
#    'node_id': 'MDQ6VXNlcjM1NTYxMg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/355612?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gsiano',
#    'html_url': 'https://github.com/gsiano',
#    'followers_url': 'https://api.github.com/users/gsiano/followers',
#    'following_url': 'https://api.github.com/users/gsiano/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gsiano/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gsiano/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gsiano/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gsiano/orgs',
#    'repos_url': 'https://api.github.com/users/gsiano/repos',
#    'events_url': 'https://api.github.com/users/gsiano/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/gsiano/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-07-19T04:27:33Z',
#   'updated_at': '2023-07-19T04:34:09Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Feature Type\r\n\r\n- [ ] Adding new functionality to pandas\r\n\r\n- [X] Changing existing functionality in pandas\r\n\r\n- [ ] Removing existing functionality in pandas\r\n\r\n\r\n### Problem Description\r\n\r\n`rolling()` allows passing a timedelta window when the DataFrame has a `DatetimeIndex`. `ewm()` requires passing the `times` parameter when using a timedelta halflife with a `DatetimeIndex`. I think `ewm()` should default to using the index as `times` if it is a `DatetimeIndex` and `halflife` is a timedelta. This way it would be more similar to the `rolling()` behavior, and in my experience I\'ve only ever seen `df.index` passed as the `times` argument. It seems counterintuitive to me to have to explicitly pass the index to `ewm()` when working with times and timedeltas.\r\n\r\n### Feature Description\r\n\r\nIf the `halflife` parameter to `ewm()` is a timedelta and `times` is not explicitly passed, use the index if it is a `DatetimeIndex`.\r\n\r\nhttps://github.com/pandas-dev/pandas/pull/54181\r\n\r\n### Alternative Solutions\r\n\r\nThe alternative would be to keep the existing behavior.\r\n\r\n### Additional Context\r\n\r\nCurrent:\r\n```\r\n>>> now = pd.Timestamp.now()\r\n>>> idx = [now + pd.Timedelta(seconds=i) for i in range(1, 4)]\r\n>>> df = pd.DataFrame({\'a\': [1,2,3]}, index=idx)\r\n>>> df.ewm(halflife=pd.Timedelta(seconds=1)).mean()\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/home/gsiano/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 11743, in ewm\r\n    return ExponentialMovingWindow(\r\n  File "/home/gsiano/.local/lib/python3.10/site-packages/pandas/core/window/ewm.py", line 386, in __init__\r\n    raise ValueError(\r\nValueError: halflife can only be a timedelta convertible argument if times is not None.\r\n>>> df.ewm(halflife=pd.Timedelta(seconds=1), times=df.index).mean()\r\n                                   a\r\n2023-07-18 10:45:18.007264  1.000000\r\n2023-07-18 10:45:19.007264  1.666667\r\n2023-07-18 10:45:20.007264  2.428571\r\n>>> \r\n```\r\n\r\nProposed:\r\n```\r\n>>> now = pd.Timestamp.now()\r\n>>> idx = [now + pd.Timedelta(seconds=i) for i in range(1, 4)]\r\n>>> df = pd.DataFrame({\'a\': [1,2,3]}, index=idx)\r\n>>> df.ewm(halflife=pd.Timedelta(seconds=1)).mean()\r\n                                   a\r\n2023-07-18 10:46:46.589891  1.000000\r\n2023-07-18 10:46:47.589891  1.666667\r\n2023-07-18 10:46:48.589891  2.428571\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54187/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54178',
#   'id': 1808994132,
#   'node_id': 'I_kwDOAA0YD85r0w9U',
#   'number': 54178,
#   'title': 'BUILD: `ValueError` raised when importing pandas due to `numpy.ndarray` size change',
#   'user': {'login': 'luke396',
#    'id': 77875500,
#    'node_id': 'MDQ6VXNlcjc3ODc1NTAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77875500?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luke396',
#    'html_url': 'https://github.com/luke396',
#    'followers_url': 'https://api.github.com/users/luke396/followers',
#    'following_url': 'https://api.github.com/users/luke396/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/luke396/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/luke396/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/luke396/subscriptions',
#    'organizations_url': 'https://api.github.com/users/luke396/orgs',
#    'repos_url': 'https://api.github.com/users/luke396/repos',
#    'events_url': 'https://api.github.com/users/luke396/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/luke396/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-07-18T03:11:27Z',
#   'updated_at': '2023-07-18T19:53:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Installation check\n\n- [X] I have read the [installation guide](https://pandas.pydata.org/pandas-docs/stable/getting_started/install.html#installing-pandas).\n\n\n### Platform\n\nLinux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.31\n\n### Installation Method\n\npip install\n\n### pandas Version\n\n2.1.0.dev0+1210.gaa4922a96b\n\n### Python Version\n\n3.10.12\n\n### Installation Logs\n\nI followed the instructions provided at https://pandas.pydata.org/docs/dev/development/contributing_environment.html and successfully installed pandas using `mamba` with the command `python -m pip install -ve . --no-build-isolation --config-settings editable-verbose=true`.\r\n\r\nHowever, when attempting to import pandas using either `pytest pandas` or `import pandas`, I encountered the following error: `ValueError: numpy.ndarray size changed, which may indicate binary incompatibility. Expected 96 from C header, but got 88 from PyObject`.\r\n\r\nI found a related issue at https://github.com/pandas-dev/pandas/issues/49683, where it was suggested to use `pip install oldest-supported-numpy` maybe resolve the problem. However, this command installs numpy-1.21.6 and did not work for me.\r\n\r\nFortunately, I received help from @Dr-Irv on Slack, who recommended using the following command: `mamba install numpy=1.23.2 -c conda-forge`. This solution worked for me.\r\n\r\nI spent a significant amount of time attempting various approaches without success. As a result, I am documenting this solution to assist anyone who may encounter a similar problem in the future, thereby saving them time and effort.\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54178/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54177',
#   'id': 1808993971,
#   'node_id': 'PR_kwDOAA0YD85VvGer',
#   'number': 54177,
#   'title': 'Fix for #54167',
#   'user': {'login': 'harikirank',
#    'id': 58730670,
#    'node_id': 'MDQ6VXNlcjU4NzMwNjcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58730670?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harikirank',
#    'html_url': 'https://github.com/harikirank',
#    'followers_url': 'https://api.github.com/users/harikirank/followers',
#    'following_url': 'https://api.github.com/users/harikirank/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/harikirank/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/harikirank/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/harikirank/subscriptions',
#    'organizations_url': 'https://api.github.com/users/harikirank/orgs',
#    'repos_url': 'https://api.github.com/users/harikirank/repos',
#    'events_url': 'https://api.github.com/users/harikirank/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/harikirank/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-07-18T03:11:14Z',
#   'updated_at': '2023-07-19T17:08:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54177',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54177',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54177.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54177.patch',
#    'merged_at': None},
#   'body': '- [x] closes #54167\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54177/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
pd.DataFrame(data1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/54226  1816552876
# 1     https://github.com/pandas-dev/pandas/pull/54225  1816520062
# 2     https://github.com/pandas-dev/pandas/pull/54224  1816512127
# 3     https://github.com/pandas-dev/pandas/pull/54223  1816498433
# 4     https://github.com/pandas-dev/pandas/pull/54222  1816496485
# 5     https://github.com/pandas-dev/pandas/pull/54221  1816492139
# 6     https://github.com/pandas-dev/pandas/pull/54220  1816445866
# 7     https://github.com/pandas-dev/pandas/pull/54219  1816415144
# 8     https://github.com/pandas-dev/pandas/pull/54218  1816253128
# 9     https://github.com/pandas-dev/pandas/pull/54217  1816206681
# 10    https://github.com/pandas-dev/pandas/pull/54216  1815855321
# 11    https://github.com/pandas-dev/pandas/pull/54214  1814840772
# 12  https://github.com/pandas-dev/pandas/issues/54212  1814501132
# 13    https://github.com/pandas-dev/pandas/pull/54209  1814325893
# 14  https://github.com/pandas-dev/pandas/issues/54206  1813812535
# 15  https://github.com/pandas-dev/pandas/issues/54204  1813437622
# 16  https://github.com/pandas-dev/pandas/issues/54203  1813359655
# 17    https://github.com/pandas-dev/pandas/pull/54200  1812855663
# 18  https://github.com/pandas-dev/pandas/issues/54199  1812736733
# 19    https://github.com/pandas-dev/pandas/pull/54198  1812706435
# 20  https://github.com/pandas-dev/pandas/issues/54195  1812112194
# 21  https://github.com/pandas-dev/pandas/issues/54194  1812052615
# 22  https://github.com/pandas-dev/pandas/issues/54193  1812036176
# 23  https://github.com/pandas-dev/pandas/issues/54192  1811897004
# 24  https://github.com/pandas-dev/pandas/issues/54191  1811847359
# 25  https://github.com/pandas-dev/pandas/issues/54190  1811692387
# 26    https://github.com/pandas-dev/pandas/pull/54188  1811292625
# 27  https://github.com/pandas-dev/pandas/issues/54187  1811119103
# 28  https://github.com/pandas-dev/pandas/issues/54178  1808994132
# 29    https://github.com/pandas-dev/pandas/pull/54177  1808993971
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85WIz4E   54226
# 1   PR_kwDOAA0YD85WItdj   54225
# 2   PR_kwDOAA0YD85WIr0n   54224
# 3   PR_kwDOAA0YD85WIot5   54223
# 4   PR_kwDOAA0YD85WIoRD   54222
# 5   PR_kwDOAA0YD85WInR3   54221
# 6   PR_kwDOAA0YD85WIdeM   54220
# 7   PR_kwDOAA0YD85WIW2J   54219
# 8   PR_kwDOAA0YD85WHz-S   54218
# 9   PR_kwDOAA0YD85WHpkR   54217
# 10  PR_kwDOAA0YD85WGdoi   54216
# 11  PR_kwDOAA0YD85WDD04   54214
# 12   I_kwDOAA0YD85sJxcM   54212
# 13  PR_kwDOAA0YD85WBSTu   54209
# 14   I_kwDOAA0YD85sHJU3   54206
# 15   I_kwDOAA0YD85sFty2   54204
# 16   I_kwDOAA0YD85sFawn   54203
# 17  PR_kwDOAA0YD85V8O2-   54200
# 18   I_kwDOAA0YD85sDCrd   54199
# 19  PR_kwDOAA0YD85V7uJj   54198
# 20   I_kwDOAA0YD85sAqNC   54195
# 21   I_kwDOAA0YD85sAbqH   54194
# 22   I_kwDOAA0YD85sAXpQ   54193
# 23   I_kwDOAA0YD85r_1qs   54192
# 24   I_kwDOAA0YD85r_pi_   54191
# 25   I_kwDOAA0YD85r_Dtj   54190
# 26  PR_kwDOAA0YD85V23Mf   54188
# 27   I_kwDOAA0YD85r83v_   54187
# 28   I_kwDOAA0YD85r0w9U   54178
# 29  PR_kwDOAA0YD85VvGer   54177
#
#                                                 title  ... closed_at  \
# 0                     DEPR: idxmin/idxmax with all-NA  ...      None
# 1   CLN/ASV: remove downcast param (deprecated) fr...  ...      None
# 2        PERF: DataFrame.transpose for pyarrow-backed  ...      None
# 3                             PERF: ArrowDtype.__eq__  ...      None
# 4                       CI/TST: Address some warnings  ...      None
# 5   CLN/ASV: DataFrame.applymap (deprecated) -> Da...  ...      None
# 6                     DOC: Simplify contributing into  ...      None
# 7                    DEPR: Series.argsort NA behavior  ...      None
# 8                     CI: Try out pre-commit.ci again  ...      None
# 9                   DOC: Fixing EX01 - Added examples  ...      None
# 10  DOC: Removed InvalidComparison and LossySetIte...  ...      None
# 11  FIX: query() and isin() fail on period type co...  ...      None
# 12  BUG: Doc build fails locally due to `rstjinja`...  ...      None
# 13  TST: Use numpy random generator for testing data   ...      None
# 14  BUG: Grouped rank incorrect behaviour with nul...  ...      None
# 15    BUG: Scatter plot has a hardcoded default value  ...      None
# 16  BUG: `AttributeError` when `rolling.agg` use `...  ...      None
# 17  CI: Bump pandas-gbq to one that doesn't pin py...  ...      None
# 18  BUG: `.query()` and `isin()` fail on period ty...  ...      None
# 19             POC: pass date_unit to values_for_json  ...      None
# 20                                              BUG:   ...      None
# 21  BUG: in a level of `MultiIndex` tz info is los...  ...      None
# 22  BUG: pd.Series.describe ignores include, exclu...  ...      None
# 23  BUG: pd.to_latex does not escape percentage si...  ...      None
# 24  BUG: `convert_dtypes(dtype_backend="pyarrow")`...  ...      None
# 25  BUG: `testing.assert_frame_equal` unhelpful er...  ...      None
# 26             Fix deprecation warning on Python 3.12  ...      None
# 27  ENH: allow `ewm()` to use a DatetimeIndex if `...  ...      None
# 28  BUILD: `ValueError` raised when importing pand...  ...      None
# 29                                     Fix for #54167  ...      None
#
#    author_association active_lock_reason  draft  \
# 0              MEMBER               None  False
# 1         CONTRIBUTOR               None  False
# 2         CONTRIBUTOR               None  False
# 3         CONTRIBUTOR               None  False
# 4              MEMBER               None  False
# 5         CONTRIBUTOR               None  False
# 6              MEMBER               None  False
# 7              MEMBER               None  False
# 8              MEMBER               None  False
# 9              MEMBER               None  False
# 10             MEMBER               None  False
# 11        CONTRIBUTOR               None   True
# 12               NONE               None    NaN
# 13             MEMBER               None  False
# 14        CONTRIBUTOR               None    NaN
# 15               NONE               None    NaN
# 16               NONE               None    NaN
# 17             MEMBER               None  False
# 18               NONE               None    NaN
# 19             MEMBER               None  False
# 20               NONE               None    NaN
# 21               NONE               None    NaN
# 22               NONE               None    NaN
# 23               NONE               None    NaN
# 24               NONE               None    NaN
# 25               NONE               None    NaN
# 26        CONTRIBUTOR               None  False
# 27        CONTRIBUTOR               None    NaN
# 28        CONTRIBUTOR               None    NaN
# 29               NONE               None  False
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   - [x] closes #51276 (Replace xxxx with the Git...
# 1                                                None
# 2   - [x] [Tests added and passed](https://pandas....
# 3   Micro-perf improvement:\r\n\r\n```\r\nimport p...
# 4                                                None
# 5                                                None
# 6   * Reduced some preamble\r\n* Updated some link...
# 7   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 8      Will need to enable the pre-commit Github app
# 9   - [x] All [code checks passed](https://pandas....
# 10  - [x] All [code checks passed](https://pandas....
# 11  - [X] closes #54199\r\n- [ ] [Tests added and ...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  This PR diff is large, but essentially it enab...
# 14  ### Pandas version checks\r\n\r\n- [X] I have ...
# 15  ### Pandas version checks\r\n\r\n- [X] I have ...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  @WillAyd this isn't working (or even compiling...
# 20  ### Pandas version checks\n\n- [X] I have chec...
# 21  ### Pandas version checks\r\n\r\n- [X] I have ...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ### Pandas version checks\r\n\r\n- [X] I have ...
# 25  ### Pandas version checks\r\n\r\n- [X] I have ...
# 26  `Constant.n` is now deprecated for removal in ...
# 27  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 28  ### Installation check\n\n- [X] I have read th...
# 29  - [x] closes #54167\r\n- [x] All [code checks ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                      None         None
# 1                      None         None
# 2                      None         None
# 3                      None         None
# 4                      None         None
# 5                      None         None
# 6                      None         None
# 7                      None         None
# 8                      None         None
# 9                      None         None
# 10                     None         None
# 11                     None         None
# 12                     None         None
# 13                     None         None
# 14                     None         None
# 15                     None         None
# 16                     None         None
# 17                     None         None
# 18                     None         None
# 19                     None         None
# 20                     None         None
# 21                     None         None
# 22                     None         None
# 23                     None         None
# 24                     None         None
# 25                     None         None
# 26                     None         None
# 27                     None         None
# 28                     None         None
# 29                     None         None
#
# [30 rows x 30 columns]

# %%
pd.DataFrame(data1,columns=['id','url','reository_url','labels_url','user'])
# Out:
#             id                                                url  \
# 0   1816552876  https://api.github.com/repos/pandas-dev/pandas...
# 1   1816520062  https://api.github.com/repos/pandas-dev/pandas...
# 2   1816512127  https://api.github.com/repos/pandas-dev/pandas...
# 3   1816498433  https://api.github.com/repos/pandas-dev/pandas...
# 4   1816496485  https://api.github.com/repos/pandas-dev/pandas...
# 5   1816492139  https://api.github.com/repos/pandas-dev/pandas...
# 6   1816445866  https://api.github.com/repos/pandas-dev/pandas...
# 7   1816415144  https://api.github.com/repos/pandas-dev/pandas...
# 8   1816253128  https://api.github.com/repos/pandas-dev/pandas...
# 9   1816206681  https://api.github.com/repos/pandas-dev/pandas...
# 10  1815855321  https://api.github.com/repos/pandas-dev/pandas...
# 11  1814840772  https://api.github.com/repos/pandas-dev/pandas...
# 12  1814501132  https://api.github.com/repos/pandas-dev/pandas...
# 13  1814325893  https://api.github.com/repos/pandas-dev/pandas...
# 14  1813812535  https://api.github.com/repos/pandas-dev/pandas...
# 15  1813437622  https://api.github.com/repos/pandas-dev/pandas...
# 16  1813359655  https://api.github.com/repos/pandas-dev/pandas...
# 17  1812855663  https://api.github.com/repos/pandas-dev/pandas...
# 18  1812736733  https://api.github.com/repos/pandas-dev/pandas...
# 19  1812706435  https://api.github.com/repos/pandas-dev/pandas...
# 20  1812112194  https://api.github.com/repos/pandas-dev/pandas...
# 21  1812052615  https://api.github.com/repos/pandas-dev/pandas...
# 22  1812036176  https://api.github.com/repos/pandas-dev/pandas...
# 23  1811897004  https://api.github.com/repos/pandas-dev/pandas...
# 24  1811847359  https://api.github.com/repos/pandas-dev/pandas...
# 25  1811692387  https://api.github.com/repos/pandas-dev/pandas...
# 26  1811292625  https://api.github.com/repos/pandas-dev/pandas...
# 27  1811119103  https://api.github.com/repos/pandas-dev/pandas...
# 28  1808994132  https://api.github.com/repos/pandas-dev/pandas...
# 29  1808993971  https://api.github.com/repos/pandas-dev/pandas...
#
#     reository_url                                         labels_url  \
# 0             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 1             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 2             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 3             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 4             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 5             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 6             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 7             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 8             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 9             NaN  https://api.github.com/repos/pandas-dev/pandas...
# 10            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 11            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 12            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 13            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 14            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 15            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 16            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 17            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 18            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 19            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 20            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 21            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 22            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 23            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 24            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 25            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 26            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 27            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 28            NaN  https://api.github.com/repos/pandas-dev/pandas...
# 29            NaN  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 2   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 3   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 4   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 5   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 6   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 7   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 8   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 9   {'login': 'DeaMariaLeon', 'id': 11835246, 'nod...
# 10  {'login': 'DeaMariaLeon', 'id': 11835246, 'nod...
# 11  {'login': 'dannyi96', 'id': 15380498, 'node_id...
# 12  {'login': 'DavidToneian', 'id': 25615622, 'nod...
# 13  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14  {'login': 'NMAC427', 'id': 9914734, 'node_id':...
# 15  {'login': 'pgorczak', 'id': 1765698, 'node_id'...
# 16  {'login': 'XytHu', 'id': 9063883, 'node_id': '...
# 17  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 18  {'login': 'davidgilbertson', 'id': 4443482, 'n...
# 19  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 20  {'login': 'strpeter', 'id': 2798595, 'node_id'...
# 21  {'login': 'maread99', 'id': 56914820, 'node_id...
# 22  {'login': 'natalymr', 'id': 31903015, 'node_id...
# 23  {'login': 'phelps-sg', 'id': 4571777, 'node_id...
# 24  {'login': 'randolf-scholz', 'id': 39696536, 'n...
# 25  {'login': 'randolf-scholz', 'id': 39696536, 'n...
# 26  {'login': 'QuLogic', 'id': 302469, 'node_id': ...
# 27  {'login': 'gsiano', 'id': 355612, 'node_id': '...
# 28  {'login': 'luke396', 'id': 77875500, 'node_id'...
# 29  {'login': 'harikirank', 'id': 58730670, 'node_...

# %%
df2 = pd.DataFrame(data1,columns=['id','url','reository_url','labels_url','user'])

# %%
df2.to_csv("res_json.csv")

# %%
df3 = pd.DataFrame(data1,columns=['user'])

# %%
df4 = list(df3['user'])
df4
# Out:
# [{'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
#   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'lukemanley',
#   'id': 8519523,
#   'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lukemanley',
#   'html_url': 'https://github.com/lukemanley',
#   'followers_url': 'https://api.github.com/users/lukemanley/followers',
#   'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#   'repos_url': 'https://api.github.com/users/lukemanley/repos',
#   'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'lukemanley',
#   'id': 8519523,
#   'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lukemanley',
#   'html_url': 'https://github.com/lukemanley',
#   'followers_url': 'https://api.github.com/users/lukemanley/followers',
#   'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#   'repos_url': 'https://api.github.com/users/lukemanley/repos',
#   'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'lukemanley',
#   'id': 8519523,
#   'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lukemanley',
#   'html_url': 'https://github.com/lukemanley',
#   'followers_url': 'https://api.github.com/users/lukemanley/followers',
#   'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#   'repos_url': 'https://api.github.com/users/lukemanley/repos',
#   'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mroeschke',
#   'id': 10647082,
#   'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mroeschke',
#   'html_url': 'https://github.com/mroeschke',
#   'followers_url': 'https://api.github.com/users/mroeschke/followers',
#   'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#   'repos_url': 'https://api.github.com/users/mroeschke/repos',
#   'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'lukemanley',
#   'id': 8519523,
#   'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lukemanley',
#   'html_url': 'https://github.com/lukemanley',
#   'followers_url': 'https://api.github.com/users/lukemanley/followers',
#   'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#   'repos_url': 'https://api.github.com/users/lukemanley/repos',
#   'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mroeschke',
#   'id': 10647082,
#   'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mroeschke',
#   'html_url': 'https://github.com/mroeschke',
#   'followers_url': 'https://api.github.com/users/mroeschke/followers',
#   'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#   'repos_url': 'https://api.github.com/users/mroeschke/repos',
#   'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
#   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mroeschke',
#   'id': 10647082,
#   'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mroeschke',
#   'html_url': 'https://github.com/mroeschke',
#   'followers_url': 'https://api.github.com/users/mroeschke/followers',
#   'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#   'repos_url': 'https://api.github.com/users/mroeschke/repos',
#   'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'DeaMariaLeon',
#   'id': 11835246,
#   'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/DeaMariaLeon',
#   'html_url': 'https://github.com/DeaMariaLeon',
#   'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#   'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#   'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#   'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#   'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'DeaMariaLeon',
#   'id': 11835246,
#   'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/DeaMariaLeon',
#   'html_url': 'https://github.com/DeaMariaLeon',
#   'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#   'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#   'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#   'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#   'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'dannyi96',
#   'id': 15380498,
#   'node_id': 'MDQ6VXNlcjE1MzgwNDk4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/15380498?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dannyi96',
#   'html_url': 'https://github.com/dannyi96',
#   'followers_url': 'https://api.github.com/users/dannyi96/followers',
#   'following_url': 'https://api.github.com/users/dannyi96/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dannyi96/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dannyi96/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dannyi96/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dannyi96/orgs',
#   'repos_url': 'https://api.github.com/users/dannyi96/repos',
#   'events_url': 'https://api.github.com/users/dannyi96/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dannyi96/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'DavidToneian',
#   'id': 25615622,
#   'node_id': 'MDQ6VXNlcjI1NjE1NjIy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/25615622?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/DavidToneian',
#   'html_url': 'https://github.com/DavidToneian',
#   'followers_url': 'https://api.github.com/users/DavidToneian/followers',
#   'following_url': 'https://api.github.com/users/DavidToneian/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/DavidToneian/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/DavidToneian/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/DavidToneian/subscriptions',
#   'organizations_url': 'https://api.github.com/users/DavidToneian/orgs',
#   'repos_url': 'https://api.github.com/users/DavidToneian/repos',
#   'events_url': 'https://api.github.com/users/DavidToneian/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/DavidToneian/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mroeschke',
#   'id': 10647082,
#   'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mroeschke',
#   'html_url': 'https://github.com/mroeschke',
#   'followers_url': 'https://api.github.com/users/mroeschke/followers',
#   'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#   'repos_url': 'https://api.github.com/users/mroeschke/repos',
#   'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'NMAC427',
#   'id': 9914734,
#   'node_id': 'MDQ6VXNlcjk5MTQ3MzQ=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/9914734?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/NMAC427',
#   'html_url': 'https://github.com/NMAC427',
#   'followers_url': 'https://api.github.com/users/NMAC427/followers',
#   'following_url': 'https://api.github.com/users/NMAC427/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/NMAC427/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/NMAC427/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/NMAC427/subscriptions',
#   'organizations_url': 'https://api.github.com/users/NMAC427/orgs',
#   'repos_url': 'https://api.github.com/users/NMAC427/repos',
#   'events_url': 'https://api.github.com/users/NMAC427/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/NMAC427/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'pgorczak',
#   'id': 1765698,
#   'node_id': 'MDQ6VXNlcjE3NjU2OTg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1765698?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pgorczak',
#   'html_url': 'https://github.com/pgorczak',
#   'followers_url': 'https://api.github.com/users/pgorczak/followers',
#   'following_url': 'https://api.github.com/users/pgorczak/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pgorczak/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/pgorczak/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pgorczak/subscriptions',
#   'organizations_url': 'https://api.github.com/users/pgorczak/orgs',
#   'repos_url': 'https://api.github.com/users/pgorczak/repos',
#   'events_url': 'https://api.github.com/users/pgorczak/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/pgorczak/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'XytHu',
#   'id': 9063883,
#   'node_id': 'MDQ6VXNlcjkwNjM4ODM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/9063883?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/XytHu',
#   'html_url': 'https://github.com/XytHu',
#   'followers_url': 'https://api.github.com/users/XytHu/followers',
#   'following_url': 'https://api.github.com/users/XytHu/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/XytHu/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/XytHu/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/XytHu/subscriptions',
#   'organizations_url': 'https://api.github.com/users/XytHu/orgs',
#   'repos_url': 'https://api.github.com/users/XytHu/repos',
#   'events_url': 'https://api.github.com/users/XytHu/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/XytHu/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'lithomas1',
#   'id': 47963215,
#   'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lithomas1',
#   'html_url': 'https://github.com/lithomas1',
#   'followers_url': 'https://api.github.com/users/lithomas1/followers',
#   'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#   'repos_url': 'https://api.github.com/users/lithomas1/repos',
#   'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'davidgilbertson',
#   'id': 4443482,
#   'node_id': 'MDQ6VXNlcjQ0NDM0ODI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/4443482?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/davidgilbertson',
#   'html_url': 'https://github.com/davidgilbertson',
#   'followers_url': 'https://api.github.com/users/davidgilbertson/followers',
#   'following_url': 'https://api.github.com/users/davidgilbertson/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/davidgilbertson/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/davidgilbertson/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/davidgilbertson/subscriptions',
#   'organizations_url': 'https://api.github.com/users/davidgilbertson/orgs',
#   'repos_url': 'https://api.github.com/users/davidgilbertson/repos',
#   'events_url': 'https://api.github.com/users/davidgilbertson/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/davidgilbertson/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'jbrockmendel',
#   'id': 8078968,
#   'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jbrockmendel',
#   'html_url': 'https://github.com/jbrockmendel',
#   'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'strpeter',
#   'id': 2798595,
#   'node_id': 'MDQ6VXNlcjI3OTg1OTU=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/2798595?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/strpeter',
#   'html_url': 'https://github.com/strpeter',
#   'followers_url': 'https://api.github.com/users/strpeter/followers',
#   'following_url': 'https://api.github.com/users/strpeter/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/strpeter/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/strpeter/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/strpeter/subscriptions',
#   'organizations_url': 'https://api.github.com/users/strpeter/orgs',
#   'repos_url': 'https://api.github.com/users/strpeter/repos',
#   'events_url': 'https://api.github.com/users/strpeter/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/strpeter/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'maread99',
#   'id': 56914820,
#   'node_id': 'MDQ6VXNlcjU2OTE0ODIw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/56914820?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/maread99',
#   'html_url': 'https://github.com/maread99',
#   'followers_url': 'https://api.github.com/users/maread99/followers',
#   'following_url': 'https://api.github.com/users/maread99/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/maread99/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/maread99/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/maread99/subscriptions',
#   'organizations_url': 'https://api.github.com/users/maread99/orgs',
#   'repos_url': 'https://api.github.com/users/maread99/repos',
#   'events_url': 'https://api.github.com/users/maread99/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/maread99/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'natalymr',
#   'id': 31903015,
#   'node_id': 'MDQ6VXNlcjMxOTAzMDE1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/31903015?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/natalymr',
#   'html_url': 'https://github.com/natalymr',
#   'followers_url': 'https://api.github.com/users/natalymr/followers',
#   'following_url': 'https://api.github.com/users/natalymr/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/natalymr/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/natalymr/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/natalymr/subscriptions',
#   'organizations_url': 'https://api.github.com/users/natalymr/orgs',
#   'repos_url': 'https://api.github.com/users/natalymr/repos',
#   'events_url': 'https://api.github.com/users/natalymr/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/natalymr/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'phelps-sg',
#   'id': 4571777,
#   'node_id': 'MDQ6VXNlcjQ1NzE3Nzc=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/4571777?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/phelps-sg',
#   'html_url': 'https://github.com/phelps-sg',
#   'followers_url': 'https://api.github.com/users/phelps-sg/followers',
#   'following_url': 'https://api.github.com/users/phelps-sg/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/phelps-sg/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/phelps-sg/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/phelps-sg/subscriptions',
#   'organizations_url': 'https://api.github.com/users/phelps-sg/orgs',
#   'repos_url': 'https://api.github.com/users/phelps-sg/repos',
#   'events_url': 'https://api.github.com/users/phelps-sg/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/phelps-sg/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'randolf-scholz',
#   'id': 39696536,
#   'node_id': 'MDQ6VXNlcjM5Njk2NTM2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/39696536?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/randolf-scholz',
#   'html_url': 'https://github.com/randolf-scholz',
#   'followers_url': 'https://api.github.com/users/randolf-scholz/followers',
#   'following_url': 'https://api.github.com/users/randolf-scholz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/randolf-scholz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/randolf-scholz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/randolf-scholz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/randolf-scholz/orgs',
#   'repos_url': 'https://api.github.com/users/randolf-scholz/repos',
#   'events_url': 'https://api.github.com/users/randolf-scholz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/randolf-scholz/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'randolf-scholz',
#   'id': 39696536,
#   'node_id': 'MDQ6VXNlcjM5Njk2NTM2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/39696536?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/randolf-scholz',
#   'html_url': 'https://github.com/randolf-scholz',
#   'followers_url': 'https://api.github.com/users/randolf-scholz/followers',
#   'following_url': 'https://api.github.com/users/randolf-scholz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/randolf-scholz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/randolf-scholz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/randolf-scholz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/randolf-scholz/orgs',
#   'repos_url': 'https://api.github.com/users/randolf-scholz/repos',
#   'events_url': 'https://api.github.com/users/randolf-scholz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/randolf-scholz/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'QuLogic',
#   'id': 302469,
#   'node_id': 'MDQ6VXNlcjMwMjQ2OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/302469?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/QuLogic',
#   'html_url': 'https://github.com/QuLogic',
#   'followers_url': 'https://api.github.com/users/QuLogic/followers',
#   'following_url': 'https://api.github.com/users/QuLogic/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/QuLogic/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/QuLogic/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/QuLogic/subscriptions',
#   'organizations_url': 'https://api.github.com/users/QuLogic/orgs',
#   'repos_url': 'https://api.github.com/users/QuLogic/repos',
#   'events_url': 'https://api.github.com/users/QuLogic/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/QuLogic/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'gsiano',
#   'id': 355612,
#   'node_id': 'MDQ6VXNlcjM1NTYxMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/355612?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gsiano',
#   'html_url': 'https://github.com/gsiano',
#   'followers_url': 'https://api.github.com/users/gsiano/followers',
#   'following_url': 'https://api.github.com/users/gsiano/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/gsiano/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/gsiano/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/gsiano/subscriptions',
#   'organizations_url': 'https://api.github.com/users/gsiano/orgs',
#   'repos_url': 'https://api.github.com/users/gsiano/repos',
#   'events_url': 'https://api.github.com/users/gsiano/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/gsiano/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'luke396',
#   'id': 77875500,
#   'node_id': 'MDQ6VXNlcjc3ODc1NTAw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/77875500?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/luke396',
#   'html_url': 'https://github.com/luke396',
#   'followers_url': 'https://api.github.com/users/luke396/followers',
#   'following_url': 'https://api.github.com/users/luke396/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/luke396/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/luke396/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/luke396/subscriptions',
#   'organizations_url': 'https://api.github.com/users/luke396/orgs',
#   'repos_url': 'https://api.github.com/users/luke396/repos',
#   'events_url': 'https://api.github.com/users/luke396/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/luke396/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'harikirank',
#   'id': 58730670,
#   'node_id': 'MDQ6VXNlcjU4NzMwNjcw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/58730670?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/harikirank',
#   'html_url': 'https://github.com/harikirank',
#   'followers_url': 'https://api.github.com/users/harikirank/followers',
#   'following_url': 'https://api.github.com/users/harikirank/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/harikirank/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/harikirank/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/harikirank/subscriptions',
#   'organizations_url': 'https://api.github.com/users/harikirank/orgs',
#   'repos_url': 'https://api.github.com/users/harikirank/repos',
#   'events_url': 'https://api.github.com/users/harikirank/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/harikirank/received_events',
#   'type': 'User',
#   'site_admin': False}]

# %%
# Convert the list of dictionaries to DataFrame
df = pd.DataFrame(df4)

# Export DataFrame to CSV
df.to_csv('output_user.csv', index=False)
