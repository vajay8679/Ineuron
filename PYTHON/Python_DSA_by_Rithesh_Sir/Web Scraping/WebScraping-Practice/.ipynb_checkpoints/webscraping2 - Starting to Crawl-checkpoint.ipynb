# %% [markdown]
# # Starting to Crawl

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bsObj = BeautifulSoup(html,'lxml')

for link in bsObj.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Wikipedia:Citation_needed
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# /wiki/EE_Limited
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(1990_film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-32
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-39
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# #cite_note-40
# #cite_note-41
# #cite_note-42
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-43
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-44
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-45
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-46
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-47
# /wiki/Tracy_Pollan
# #cite_note-48
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-49
# #cite_note-50
# /wiki/The_Times
# /wiki/God
# #cite_note-51
# /wiki/Antireligion
# #cite_note-52
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-53
# #cite_note-54
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-55
# #cite_note-56
# #cite_note-57
# #cite_note-58
# /wiki/Apollo_13_(film)
# #cite_note-59
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-60
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-61
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-62
# /wiki/Denver_Film_Festival
# #cite_note-63
# /wiki/Phoenix_Film_Festival
# #cite_note-64
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-65
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-66
# /wiki/Seattle_International_Film_Festival
# #cite_note-67
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.sixdegrees.org/
# #cite_ref-44
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-45
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-46
# http://baconbros.com/
# #cite_ref-47
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-48
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-49
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-50
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-51
# #cite_ref-52
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_53-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-54
# #cite_ref-55
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-56
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-57
# http://www.drawtheline.org/sign-now/
# #cite_ref-58
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-59
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-60
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-61
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-62
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-63
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-64
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-65
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-66
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-67
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# https://en.wikipedia.org/w/index.php?title=Template:Golden_Globe_Best_Actor_TV_Miniseries_Film&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# /wiki/ISNI_(identifier)
# https://isni.org/isni/0000000121291300
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/39570812
# https://www.worldcat.org/identities/lccn-n88034930/
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://d-nb.info/gnd/124109659
# http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://id.loc.gov/authorities/names/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# https://lod.nl.go.kr/resource/KAC2020K8226
# http://data.bibliotheken.nl/id/thes/p147880998
# http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&NU=1&IM=4&WI=9810630778405606
# http://id.worldcat.org/fast/242183/
# /wiki/MBA_(identifier)
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/RERO_(identifier)
# http://data.rero.ch/02-A016294166
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/084292652
# https://www.idref.fr/067287832
# /wiki/Trove_(identifier)
# https://trove.nla.gov.au/people/1189569
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1111670168
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_October_2021
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_WORLDCATID_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_LNB_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_NTA_identifiers
# /wiki/Category:Articles_with_PLWABN_identifiers
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_MusicBrainz_identifiers
# /wiki/Category:Articles_with_RERO_identifiers
# /wiki/Category:Articles_with_SNAC-ID_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_multiple_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1111670168
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1111670168&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
#with regax

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bsObj = BeautifulSoup(html,'lxml')

for link in bsObj.find("div",{"id":"bodyContent"}).findAll('a',href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
         print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/EE_Limited
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/EE_(telecommunications_company)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/God
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/ISNI_(identifier)
# /wiki/VIAF_(identifier)
# /wiki/MBA_(identifier)
# /wiki/RERO_(identifier)
# /wiki/SUDOC_(identifier)
# /wiki/Trove_(identifier)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())

def getLinks(addArticleUrl):
    html = urlopen('http://en.wikipedia.org' + addArticleUrl)
    bsObj = BeautifulSoup(html,'lxml')
    return bsObj.find('div',{'id':'bodyContent'}).findAll('a',href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')

while len(links) > 0:
    newArticle = links[random.randint(0,len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Magneto_(Marvel_Comics)
# /wiki/Feral_(character)
# /wiki/Icarus_(comics)
# /wiki/Iron_Cross_(Marvel_Comics)
# /wiki/Blonde_Phantom
# /wiki/Inker
# /wiki/Manga
# /wiki/Russo-Japanese_War
# /wiki/Russo-Swedish_War_(1788%E2%80%931790)
# /wiki/Lomonosov,_Russia
# /wiki/Municipal_Okrug_65
# /wiki/Sestroretsk
# /wiki/Yekateringofsky_Municipal_Okrug
# /wiki/Pulkovsky_meridian_Municipal_Okrug
# /wiki/Yekateringofsky_Municipal_Okrug
# /wiki/Moskovsky_District,_Saint_Petersburg
# /wiki/Tsentralny_District,_Saint_Petersburg
# /wiki/Ligovka-Yamskaya_Municipal_Okrug
# /wiki/Smolninskoye_Municipal_Okrug
# /wiki/Administrative_divisions_of_Saint_Petersburg
# /wiki/Administrative_divisions_of_North_Ossetia%E2%80%93Alania
# /wiki/Administrative_divisions_of_Zabaykalsky_Krai
# /wiki/Zhireken
# /wiki/Karymskoye
# /wiki/Nerchinsky_District
# /wiki/Nerchinsk
# /wiki/Zhireken
# /wiki/Priiskovy,_Zabaykalsky_Krai
# /wiki/Balyaga
# /wiki/Sretensk
# /wiki/Drovyanaya
# /wiki/Strategic_Rocket_Forces
# /wiki/UR-200
# /wiki/R-5_Pobeda
# /wiki/S-400_missile_system
# /wiki/Union_State
# /wiki/Prime_Minister_of_Russia
# /wiki/President_of_Cyprus
# /wiki/President_of_Georgia
# /wiki/List_of_Georgian_battles
# /wiki/Georgia_(country)
# /wiki/Revolution_of_1905
# /wiki/Old_Style_and_New_Style_dates
# /wiki/Oxford_Academic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 16>()
#      17 newArticle = links[random.randint(0,len(links)-1)].attrs['href']
#      18 print(newArticle)
# ---> 19 links = getLinks(newArticle)
#
# Input In [11], in getLinks(addArticleUrl)
#       9 def getLinks(addArticleUrl):
#      10     html = urlopen('http://en.wikipedia.org' + addArticleUrl)
# ---> 11     bsObj = BeautifulSoup(html,'lxml')
#      12     return bsObj.find('div',{'id':'bodyContent'}).findAll('a',href=re.compile('^(/wiki/)((?!:).)*$'))
#
# File ~/.local/lib/python3.8/site-packages/bs4/__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File ~/.local/lib/python3.8/site-packages/bs4/__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File ~/.local/lib/python3.8/site-packages/bs4/builder/_lxml.py:378, in LXMLTreeBuilder.feed(self, markup)
#     376 try:
#     377     self.parser = self.parser_for(encoding)
# --> 378     self.parser.feed(markup)
#     379     self.parser.close()
#     380 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src/lxml/parser.pxi:1256, in lxml.etree._FeedParser.feed()
#
# File src/lxml/parser.pxi:1376, in lxml.etree._FeedParser.feed()
#
# File src/lxml/parsertarget.pxi:168, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src/lxml/etree.pyx:333, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src/lxml/saxparser.pxi:443, in lxml.etree._handleSaxTargetStartNoNs()
#
# File src/lxml/saxparser.pxi:458, in lxml.etree._callTargetSaxStart()
#
# File src/lxml/parsertarget.pxi:94, in lxml.etree._PythonSaxParserTarget._handleSaxStart()
#
# File ~/.local/lib/python3.8/site-packages/bs4/builder/_lxml.py:289, in LXMLTreeBuilderForXML.start(self, name, attrs, nsmap)
#     285 # Namespaces are in play. Find any attributes that came in
#     286 # from lxml with namespaces attached to their names, and
#     287 # turn then into NamespacedAttribute objects.
#     288 new_attrs = {}
# --> 289 for attr, value in list(attrs.items()):
#     290     namespace, attr = self._getNsTag(attr)
#     291     if namespace is None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Crawling an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinkss(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org'+pageUrl)
    bsObj = BeautifulSoup(html,'lxml')
    for link in bsObj.findAll('a',href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newUrl = link.attrs['href']
                print(newUrl)
                pages.add(newUrl)
                getLinkss(newUrl)
                
getLinkss("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_page_protection/Administrator_instructions
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy#Semi-protection
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/Wikipedia:WikiProject_Poland
# /wiki/Wikipedia:Protection_policy#pending
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# /wiki/User:Emb021
# /wiki/File:Flag_of_the_United_States.svg
# /wiki/Scalable_Vector_Graphics
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 18>()
#      15                 pages.add(newUrl)
#      16                 getLinkss(newUrl)
# ---> 18 getLinkss("")
#
# Input In [13], in getLinkss(pageUrl)
#      14 print(newUrl)
#      15 pages.add(newUrl)
# ---> 16 getLinkss(newUrl)
#
# Input In [13], in getLinkss(pageUrl)
#      14 print(newUrl)
#      15 pages.add(newUrl)
# ---> 16 getLinkss(newUrl)
#
#     [... skipping similar frames: getLinkss at line 16 (21 times)]
#
# Input In [13], in getLinkss(pageUrl)
#      14 print(newUrl)
#      15 pages.add(newUrl)
# ---> 16 getLinkss(newUrl)
#
# Input In [13], in getLinkss(pageUrl)
#       6 def getLinkss(pageUrl):
#       7     global pages
# ----> 8     html = urlopen('http://en.wikipedia.org'+pageUrl)
#       9     bsObj = BeautifulSoup(html,'lxml')
#      10     for link in bsObj.findAll('a',href=re.compile('^(/wiki/)')):
#
# File /usr/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File /usr/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File /usr/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /usr/lib/python3.8/urllib/request.py:1383, in HTTPHandler.http_open(self, req)
#    1382 def http_open(self, req):
# -> 1383     return self.do_open(http.client.HTTPConnection, req)
#
# File /usr/lib/python3.8/urllib/request.py:1358, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1356     except OSError as err: # timeout error
#    1357         raise URLError(err)
# -> 1358     r = h.getresponse()
#    1359 except:
#    1360     h.close()
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Crawling and collecting data

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()

def getLinksss(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org'+pageUrl)
    bsObj = BeautifulSoup(html,'lxml')
    
    try:
        print("H1 :",bsObj.h1.get_text())
        print("First Paragraph :\n",bsObj.find(id='mw-content-text').findAll("p")[0])
        print("Edit Link :",bsObj.find(id='ca-edit').find("a").attrs["href"])
    except AttributeError:
        print("Something went wrong !!!!!!!!!!!!!!")
        
    for link in bsObj.findAll('a',href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                newUrl = link.attrs['href']
                print("---------------------------------------------------------\n"+newUrl)
                pages.add(newUrl)
                getLinksss(newUrl)
                
getLinksss("")
# Out:
# H1 : Main Page
# First Paragraph :
#  <p><i><b><a href="/wiki/Rachel_Dyer" title="Rachel Dyer">Rachel Dyer</a></b></i> is a <a href="/wiki/Gothic_fiction" title="Gothic fiction">Gothic novel</a> of <a href="/wiki/Historical_fiction" title="Historical fiction">historical fiction</a> by American writer <a href="/wiki/John_Neal_(writer)" title="John Neal (writer)">John Neal</a> <i>(depicted)</i>. Published in 1828 in <a href="/wiki/Maine" title="Maine">Maine</a>, it is the first <a href="/wiki/Bookbinding" title="Bookbinding">bound</a> novel about the <a href="/wiki/Salem_witch_trials" title="Salem witch trials">Salem witch trials</a>. It garnered little critical notice in its day but influenced works by better-known authors. It is best remembered for "Unpublished Preface", an <a href="/wiki/American_literary_nationalism" title="American literary nationalism">American literary nationalist</a> essay that precedes the story. Following a darkly poetic narrative, the story centers around historical figure <a href="/wiki/George_Burroughs" title="George Burroughs">George Burroughs</a> and fictional witch hysteria victim Rachel Dyer. About two-thirds of the story takes place in the courtroom, following the trials of  alleged witches. Themes include justice, sexual frustration, mistreatment of <a href="/wiki/Native_Americans_in_the_United_States" title="Native Americans in the United States">American Indians</a> by <a href="/wiki/Puritans" title="Puritans">Puritans</a>, the myth of national American unity in the face of <a href="/wiki/Cultural_pluralism" title="Cultural pluralism">pluralist</a> reality, and <a href="/wiki/Republicanism_in_the_United_States" title="Republicanism in the United States">republican</a> ideals as an antidote for <a href="/wiki/Old_World" title="Old World">Old World</a> precedent. The novel experiments with speech patterns, dialogue, and transcriptions of <a href="/wiki/Eastern_New_England_English" title="Eastern New England English">Yankee dialect</a> that Neal hoped would come to characterize American literature. (<b><a href="/wiki/Rachel_Dyer" title="Rachel Dyer">Full article...</a></b>)
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia
# H1 : Wikipedia
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Protection_policy#semi
# H1 : Wikipedia:Protection policy
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Requests_for_page_protection
# H1 : Wikipedia:Requests for page protection
# First Paragraph :
#  <p>This page is for requesting that a page, file or template be <b>protected</b>. Please read up on the <a href="/wiki/Wikipedia:Protection_policy" title="Wikipedia:Protection policy">protection policy</a>. Full protection is used to stop edit warring between multiple users or to prevent vandalism to <a href="/wiki/Wikipedia:High-risk_templates" title="Wikipedia:High-risk templates">high-risk templates</a>; semi-protection and pending changes are usually used only to prevent IP and new user vandalism (see the <a href="/wiki/Wikipedia:Rough_guide_to_semi-protection" title="Wikipedia:Rough guide to semi-protection">rough guide to semi-protection</a>); and move protection is used to stop <a href="/wiki/Wikipedia:Moving_a_page" title="Wikipedia:Moving a page">pagemove</a> revert wars. Extended confirmed protection is used where semi-protection has proved insufficient (see the <a href="/wiki/Wikipedia:Rough_guide_to_extended_confirmed_protection" title="Wikipedia:Rough guide to extended confirmed protection">rough guide to extended confirmed protection</a>)
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Requests_for_page_protection/Administrator_instructions
# H1 : Wikipedia:Requests for page protection/Administrator instructions
# First Paragraph :
#  <p>Administrator instructions for <b>Requests for Page Protection</b>:
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Requests_for_page_protection/Administrator_instructions&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Protection_policy
# H1 : Wikipedia:Protection policy
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Lists_of_protected_pages
# H1 : Wikipedia:Lists of protected pages
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Protection_policy#Semi-protection
# H1 : Wikipedia:Protection policy
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Perennial_proposals
# H1 : Wikipedia:Perennial proposals
# First Paragraph :
#  <p>This is a list of things that have frequently been proposed on Wikipedia, and have been <a class="mw-redirect" href="/wiki/Wikipedia:Rejected_proposals" title="Wikipedia:Rejected proposals">rejected by the community</a> several times in the past. It should be noted that merely listing something on this page does not mean it will never happen, but that it has been discussed before and never met consensus.  <a class="mw-redirect" href="/wiki/Wikipedia:Consensus_can_change" title="Wikipedia:Consensus can change">Consensus can change</a>, and some proposals that remained on this page for a long time have finally been proposed in a way that reached consensus, but you should address rebuttals raised in the past if you make a proposal along these lines.  If you feel you would still like to do one of these proposals, then raise it at the <a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Village pump">village pump</a>.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Perennial_proposals&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# H1 : Wikipedia:Reliable sources/Perennial sources
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Reliable_sources/Perennial_sources&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Reliable_sources
# H1 : Wikipedia:Reliable sources
# First Paragraph :
#  <p>Wikipedia articles should be based on <b>reliable, published sources</b>, making sure that <strong>all majority and significant minority views</strong> that have appeared in those sources are covered (see <a href="/wiki/Wikipedia:Neutral_point_of_view" title="Wikipedia:Neutral point of view">Wikipedia:Neutral point of view</a>).  If no reliable sources can be found on a topic, <a href="/wiki/Wikipedia:Notability" title="Wikipedia:Notability">Wikipedia should not have an article on it</a>.
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:WikiProject_Reliability
# H1 : Wikipedia:WikiProject Reliability
# First Paragraph :
#  <p>Hello, and welcome to <b>WikiProject Reliability</b>. This WikiProject is dedicated to improving the <a class="mw-redirect" href="/wiki/Wikipedia:RS" title="Wikipedia:RS">reliability</a> of Wikipedia articles. We ensure that articles are supported by <a class="mw-redirect" href="/wiki/Wikipedia:RS" title="Wikipedia:RS">reliable sources</a>, answer inquiries on the <a class="mw-redirect" href="/wiki/Wikipedia:RSN" title="Wikipedia:RSN">reliable sources noticeboard</a>, and maintain a <a class="mw-redirect" href="/wiki/Wikipedia:RSP" title="Wikipedia:RSP">list of frequently discussed sources</a>. This project works to achieve the goals of the <a class="mw-redirect" href="/wiki/Wikipedia:V" title="Wikipedia:V">verifiability</a> and <a class="mw-redirect" href="/wiki/Wikipedia:OR" title="Wikipedia:OR">no original research</a> policies. If you would like to help, please <a href="#Participants">join</a> the project, participate on the <a href="/wiki/Wikipedia_talk:WikiProject_Reliability" title="Wikipedia talk:WikiProject Reliability">talk page</a> and see the <a href="#Open_tasks">open tasks</a> below.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:WikiProject_Reliability&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:WRE
# H1 : Wikipedia:WikiProject Resource Exchange
# First Paragraph :
#  <p><b>Departments</b>
# </p>
# Edit Link : /w/index.php?title=Wikipedia:WikiProject_Resource_Exchange&action=edit
# ---------------------------------------------------------
# /wiki/File:People_icon.svg
# H1 : File:People icon.svg
# First Paragraph :
#  <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/3/37/People_icon.svg" title="People icon.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 13 KB)</span>
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# H1 : Pages that link to "File:People icon.svg"
# First Paragraph :
#  <p>The following pages link to <b id="specialDeleteTarget"><a href="/wiki/File:People_icon.svg" title="File:People icon.svg">File:People icon.svg</a></b> <span id="specialDeleteLink"></span>
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Help:What_links_here
# H1 : Help:What links here
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# H1 : Wikipedia:Project namespace
# First Paragraph :
#  <p>Project pages are for information or discussion about Wikipedia. They should be used to allow Wikipedians to better participate in the community, and not used to excess for unrelated purposes nor to bring the project into disrepute.</p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Policies_and_guidelines
# H1 : Wikipedia:Policies and guidelines
# First Paragraph :
#  <p>Wikipedia's <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:WikiProject_Politics
# H1 : Wikipedia:WikiProject Politics
# First Paragraph :
#  <p>Welcome to <b>WikiProject Politics</b>. A <a href="/wiki/Wikipedia:WikiProject" title="Wikipedia:WikiProject">WikiProject</a> is a group of pages in the "Wikipedia" <a href="/wiki/Wikipedia:Namespace" title="Wikipedia:Namespace">article namespace</a> that are devoted to the management of a specific topic or family of topics within Wikipedia; and, simultaneously, a <a href="/wiki/Wikipedia:WikiProject_Politics/Participants" title="Wikipedia:WikiProject Politics/Participants">group of editors</a> who use those pages to collaborate on encyclopedic work. It is not a place to write encyclopedia articles directly, but a resource to help coordinate and organize the writing and editing of those articles. This group focuses on articles in the broad field of <a href="/wiki/Politics" title="Politics">Politics</a>.  This page and its subpages contain their suggestions; it is hoped that this project will help to focus the efforts of other Wikipedians. You may sign up for the project on the <a href="/wiki/Wikipedia:WikiProject_Politics/Participants" title="Wikipedia:WikiProject Politics/Participants">Participants</a> list below.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:WikiProject_Politics&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:WikiProject_Poland
# H1 : Wikipedia:WikiProject Poland
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Edit Link : /w/index.php?title=Wikipedia:WikiProject_Poland&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Protection_policy#pending
# H1 : Wikipedia:Protection policy
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# H1 : Wikipedia:WikiProject Parliamentary Procedure
# First Paragraph :
#  <p>talked*<a href="/wiki/User:Newyorkbrad" title="User:Newyorkbrad">Network8brad</a> (<a class="new" href="/w/index.php?title=User_BABEL_talk:Newyorkbrad&amp;action=edit&amp;redlink=1" title="User BABEL talk:Newyorkbrad (page does not exist)">talk</a>)
# </p>
# Edit Link : /w/index.php?title=Wikipedia:WikiProject_Parliamentary_Procedure&action=edit
# ---------------------------------------------------------
# /wiki/User:Emb021
# H1 : User:Emb021
# First Paragraph :
#  <p>Michael R. Brown
# </p>
# Edit Link : /w/index.php?title=User:Emb021&action=edit
# ---------------------------------------------------------
# /wiki/File:Flag_of_the_United_States.svg
# H1 : File:Flag of the United States.svg
# First Paragraph :
#  <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/a/a4/Flag_of_the_United_States.svg" title="Flag of the United States.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 1,235 × 650 pixels, file size: 899 bytes)</span>
# </p>
# Edit Link : /w/index.php?title=File:Flag_of_the_United_States.svg&action=edit
# ---------------------------------------------------------
# /wiki/Scalable_Vector_Graphics
# H1 : Scalable Vector Graphics
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Edit Link : /w/index.php?title=Scalable_Vector_Graphics&action=edit
# ---------------------------------------------------------
# /wiki/SVG_(disambiguation)
# H1 : SVG (disambiguation)
# First Paragraph :
#  <p><b><a class="mw-redirect" href="/wiki/SVG" title="SVG">SVG</a></b> or Scalable Vector Graphics is a vector image format for two-dimensional computer graphics.
# </p>
# Edit Link : /w/index.php?title=SVG_(disambiguation)&action=edit
# ---------------------------------------------------------
# /wiki/SVG
# H1 : Scalable Vector Graphics
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Edit Link : /w/index.php?title=Scalable_Vector_Graphics&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:SVG_help
# H1 : Wikipedia:SVG help
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Edit Link : /w/index.php?title=Wikipedia:SVG_help&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Graphic_Lab/Resources/SVG
# H1 : Wikipedia:Graphics Lab/Resources/SVG
# First Paragraph :
#  <p><a class="mw-redirect" href="/wiki/SVG" title="SVG">SVG</a> (Scalable Vector Graphics) resources. Why SVG, one might ask? Look to the image on the right. SVG images stored at Wikipedia or on the <a href="/wiki/Wikimedia_Commons" title="Wikimedia Commons">Wikimedia Commons</a> aren't actually what you see in your browser when viewing Wikipedia articles. <a href="/wiki/MediaWiki" title="MediaWiki">MediaWiki</a> converts the SVG image to a <a href="/wiki/Portable_Network_Graphics" title="Portable Network Graphics">PNG</a> image. The SVG format is the working format of the stored image so that people can more easily convert images for use in different languages. If you're using a browser other than <a href="/wiki/Internet_Explorer" title="Internet Explorer">Internet Explorer</a>, just keep clicking the image and you'll eventually get the full-size image, which will be the SVG version. For example; keep clicking the image to the right. For more info please see: <a class="extiw" href="https://commons.wikimedia.org/wiki/Commons:File_types#SVG" title="commons:Commons:File types">Commons:File types#SVG</a>.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Graphics_Lab/Resources/SVG&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Graphics_Lab
# H1 : Wikipedia:Graphics Lab
# First Paragraph :
#  <p>The <b>Graphics Lab</b> helps improve all graphical content stored on <a class="extiw" href="https://commons.wikimedia.org/wiki/Main_Page" title="commons:Main Page">Wikimedia Commons</a> and the English Wikipedia.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Graphics_Lab&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Graphics_Lab/Illustration_workshop
# H1 : Wikipedia:Graphics Lab/Illustration workshop
# First Paragraph :
#  <p>The <b><a href="/wiki/Wikipedia:Graphics_Lab" title="Wikipedia:Graphics Lab">Graphics Lab</a></b> is a project to improve the graphical content of the Wikimedia projects. Requests for image improvements can be added to the workshop pages: <a class="mw-redirect" href="/wiki/Wikipedia:GL/ILL" title="Wikipedia:GL/ILL">Illustrations</a>, <a class="mw-redirect" href="/wiki/Wikipedia:GL/PHOTO" title="Wikipedia:GL/PHOTO">Photographs</a> and <a class="mw-redirect" href="/wiki/Wikipedia:GL/MAP" title="Wikipedia:GL/MAP">Maps</a>. For questions or suggestions one can use the talk pages: <a href="/wiki/Wikipedia_talk:Graphics_Lab" title="Wikipedia talk:Graphics Lab">Talk:Graphics Lab</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop" title="Wikipedia talk:Graphics Lab/Illustration workshop">Talk:Illustrations</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop" title="Wikipedia talk:Graphics Lab/Photography workshop">Talk:Photographs</a> and <a href="/wiki/Wikipedia_talk:Graphics_Lab/Map_workshop" title="Wikipedia talk:Graphics Lab/Map workshop">Talk:Maps</a>.<br/>
# <b>This specific page</b> is the requests page for the illustration workshop. Anyone can make a request for an illustration to be improved or created for a Wikipedia article.  Clicking the "New Request" button will bring you to a standard template for submitting requests, as well as general advice that should be followed.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Graphics_Lab/Illustration_workshop&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Graphics_Lab/Photography_workshop
# H1 : Wikipedia:Graphics Lab/Photography workshop
# First Paragraph :
#  <p>The <b><a href="/wiki/Wikipedia:Graphics_Lab" title="Wikipedia:Graphics Lab">Graphics Lab</a></b> is a project to improve the graphical content of the Wikimedia projects. Requests for image improvements can be added to the workshop pages: <a class="mw-redirect" href="/wiki/Wikipedia:GL/ILL" title="Wikipedia:GL/ILL">Illustrations</a>, <a class="mw-redirect" href="/wiki/Wikipedia:GL/PHOTO" title="Wikipedia:GL/PHOTO">Photographs</a> and <a class="mw-redirect" href="/wiki/Wikipedia:GL/MAP" title="Wikipedia:GL/MAP">Maps</a>. For questions or suggestions one can use the talk pages: <a href="/wiki/Wikipedia_talk:Graphics_Lab" title="Wikipedia talk:Graphics Lab">Talk:Graphics Lab</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop" title="Wikipedia talk:Graphics Lab/Illustration workshop">Talk:Illustrations</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop" title="Wikipedia talk:Graphics Lab/Photography workshop">Talk:Photographs</a> and <a href="/wiki/Wikipedia_talk:Graphics_Lab/Map_workshop" title="Wikipedia talk:Graphics Lab/Map workshop">Talk:Maps</a>.<br/>
# <b>This specific page</b> is the requests page for the photography workshop. Anyone can make a request for a photograph to be improved for a Wikipedia article. The standard format for making a request is shown below, along with general advice, and should be followed.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Graphics_Lab/Photography_workshop&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Graphics_Lab/Map_workshop
# H1 : Wikipedia:Graphics Lab/Map workshop
# First Paragraph :
#  <p>The <b><a href="/wiki/Wikipedia:Graphics_Lab" title="Wikipedia:Graphics Lab">Graphics Lab</a></b> is a project to improve the graphical content of the Wikimedia projects. Requests for image improvements can be added to the workshop pages: <a class="mw-redirect" href="/wiki/Wikipedia:GL/ILL" title="Wikipedia:GL/ILL">Illustrations</a>, <a class="mw-redirect" href="/wiki/Wikipedia:GL/PHOTO" title="Wikipedia:GL/PHOTO">Photographs</a> and <a class="mw-redirect" href="/wiki/Wikipedia:GL/MAP" title="Wikipedia:GL/MAP">Maps</a>. For questions or suggestions one can use the talk pages: <a href="/wiki/Wikipedia_talk:Graphics_Lab" title="Wikipedia talk:Graphics Lab">Talk:Graphics Lab</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop" title="Wikipedia talk:Graphics Lab/Illustration workshop">Talk:Illustrations</a>, <a href="/wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop" title="Wikipedia talk:Graphics Lab/Photography workshop">Talk:Photographs</a> and <a href="/wiki/Wikipedia_talk:Graphics_Lab/Map_workshop" title="Wikipedia talk:Graphics Lab/Map workshop">Talk:Maps</a>.<br/>
# <b>This specific page</b> is the requests page for the Map workshop. Anyone can make a request for a map to be created or improved for a Wikipedia article. The standard format for making a request is shown below, along with general advice, and should be followed.<br/>
# You are encouraged to share information and request advice from others. Also see <a href="/wiki/Wikipedia:WikiProject_Maps/Conventions" title="Wikipedia:WikiProject Maps/Conventions">possible conventions toolbox</a>, <a href="/wiki/Wikipedia:Graphics_Lab/Resources/Tutorials" title="Wikipedia:Graphics Lab/Resources/Tutorials">map tutorials</a> and <a href="/wiki/User:JaneVannin/translations" title="User:JaneVannin/translations">topographic map tutorials</a>.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Graphics_Lab/Map_workshop&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Shortcut
# H1 : Wikipedia:Shortcut
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Keyboard_shortcuts
# H1 : Wikipedia:Keyboard shortcuts
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:WikiProject_Kansas
# H1 : Wikipedia:WikiProject Kansas
# First Paragraph :
#  <p><span style="font-size:100%;font-weight:bold;border: none; margin: 0; padding:0; padding-bottom:.1em; color:#FFD700;"><a class="image" href="/wiki/File:Seal_of_Kansas.svg"><img alt="Seal of Kansas.svg" data-file-height="600" data-file-width="600" decoding="async" height="48" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/Seal_of_Kansas.svg/48px-Seal_of_Kansas.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/Seal_of_Kansas.svg/72px-Seal_of_Kansas.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/45/Seal_of_Kansas.svg/96px-Seal_of_Kansas.svg.png 2x" width="48"/></a><br/><i>Welcome</i></span>
# </p>
# Edit Link : /w/index.php?title=Wikipedia:WikiProject_Kansas&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:WikiProject
# H1 : Wikipedia:WikiProject
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/WikiProject
# H1 : WikiProject
# First Paragraph :
#  <p>A <b>WikiProject</b>, or <b>Wikiproject</b>, is a <a href="/wiki/Wikimedia_movement" title="Wikimedia movement">Wikimedia movement</a> <a href="/wiki/Affinity_group" title="Affinity group">affinity group</a> for contributors with shared goals. WikiProjects are prevalent within the largest wiki, Wikipedia, and exist to varying degrees within <a class="mw-redirect" href="/wiki/Wikimedia_project" title="Wikimedia project">sister projects</a> such as <a href="/wiki/Wiktionary" title="Wiktionary">Wiktionary</a>, <a href="/wiki/Wikiquote" title="Wikiquote">Wikiquote</a>, <a href="/wiki/Wikidata" title="Wikidata">Wikidata</a>, and <a href="/wiki/Wikisource" title="Wikisource">Wikisource</a>. They also exist in different languages, and translation of articles is a form of their collaboration. During the <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">COVID-19 pandemic</a>, <a href="/wiki/CBS_News" title="CBS News">CBS News</a> noted the role of Wikipedia's WikiProject Medicine in maintaining the accuracy of articles related to the disease.<sup class="reference" id="cite_ref-COVID-19_1-0"><a href="#cite_note-COVID-19-1">[1]</a></sup> Another WikiProject that has drawn attention is WikiProject Women Scientists, which was profiled by <i><a class="mw-redirect" href="/wiki/Smithsonian_Magazine" title="Smithsonian Magazine">Smithsonian</a></i> for its efforts to improve coverage of women scientists which the profile noted had "helped increase the number of female scientists on Wikipedia from around 1,600 to over 5,000".<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </p>
# Edit Link : /w/index.php?title=WikiProject&action=edit
# ---------------------------------------------------------
# /wiki/Wikimedia_movement
# H1 : Wikimedia movement
# First Paragraph :
#  <p>According to the <a href="/wiki/Wikimedia_Foundation" title="Wikimedia Foundation">Wikimedia Foundation</a>, the <b>Wikimedia movement</b> is the global community of contributors to the <a href="#Projects">Wikimedia projects</a>.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup><sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> This community directly builds and administers the projects.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> It is committed to using <a href="/wiki/Open_standard" title="Open standard">open standards</a> and <a href="/wiki/Open-source_software" title="Open-source software">software</a>.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
# </p>
# Edit Link : /w/index.php?title=Wikimedia_movement&action=edit
# ---------------------------------------------------------
# /wiki/Talk:Wikimedia_movement
# H1 : Talk:Wikimedia movement
# First Paragraph :
#  <p><span data-mw-comment-start="" id="c-PrimeBOT-2022-01-17T12:57:00.000Z-Wiki_Education_Foundation-supported_course_assignment"></span><a class="image" href="/wiki/File:Sciences_humaines.svg"><img alt="Sciences humaines.svg" data-file-height="256" data-file-width="256" decoding="async" height="40" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Sciences_humaines.svg/40px-Sciences_humaines.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Sciences_humaines.svg/60px-Sciences_humaines.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Sciences_humaines.svg/80px-Sciences_humaines.svg.png 2x" width="40"/></a> This article is or was the subject of a Wiki Education Foundation-supported course assignment. Further details are available <a href="/wiki/Wikipedia:Wiki_Ed/University_of_California,_Berkeley/Social_Movements_and_Social_Media_(Fall_2017)" title="Wikipedia:Wiki Ed/University of California, Berkeley/Social Movements and Social Media (Fall 2017)">on the course page</a>.  Peer reviewers: <a href="/wiki/User:Andrewmcfar" title="User:Andrewmcfar">Andrewmcfar</a>.
# </p>
# Edit Link : /w/index.php?title=Talk:Wikimedia_movement&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Talk_page_guidelines
# H1 : Wikipedia:Talk page guidelines
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Help:Talk_pages
# H1 : Help:Talk pages
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Help:Template
# H1 : Help:Template
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Template_index
# H1 : Wikipedia:Template index
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Manual_of_Style/Trademarks
# H1 : Wikipedia:Manual of Style/Trademarks
# First Paragraph :
#  <p><b><a href="/wiki/Trademark" title="Trademark">Trademarks</a></b> include words and short phrases used by legal entities to identify themselves and their products and services. Often, these names are written in several ways with variations in capitalization, punctuation, and formatting. The advice in this page also applies to names and phrases used to identify individuals, movements, groups, forums, projects, events, and other non-commercial entities and their output.
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Manual_of_Style/Trademarks&action=edit
# ---------------------------------------------------------
# /wiki/Wikipedia:Manual_of_Style
# H1 : Wikipedia:Manual of Style
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Policies_and_guidelines#guide
# H1 : Wikipedia:Policies and guidelines
# First Paragraph :
#  <p>Wikipedia's <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:List_of_policies#Procedural
# H1 : Wikipedia:List of policies
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Template:Nutshell
# H1 : Template:Nutshell
# First Paragraph :
#  <p>This template presents a <a class="mw-redirect" href="/wiki/Wikipedia:TRITE" title="Wikipedia:TRITE">concise</a> summary at the top of  <a href="/wiki/Wikipedia:Administration#Data_structure_and_development" title="Wikipedia:Administration">administration pages</a>. It is placed below the title and other infoboxes and above the first paragraph of the main body.
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Protection_policy#template
# H1 : Wikipedia:Protection policy
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Party_and_person
# H1 : Wikipedia:Party and person
# First Paragraph :
#  <p>Different content policies and guidelines use slightly different standards.  One of the commonly misunderstood distinctions is between "secondary source" and "third party".
# </p>
# Edit Link : /w/index.php?title=Wikipedia:Party_and_person&action=edit
# ---------------------------------------------------------
# /wiki/File:Essay.svg
# H1 : File:Essay.svg
# First Paragraph :
#  <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/7e/Essay.svg" title="Essay.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 35 × 42 pixels, file size: 8 KB)</span>
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/File:Essay.png
# H1 : File:Wikipedia Essay icon.png
# First Paragraph :
#  <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/2/2d/Wikipedia_Essay_icon.png" title="Wikipedia Essay icon.png">Wikipedia_Essay_icon.png</a> ‎<span class="fileInfo">(30 × 35 pixels, file size: 2 KB, MIME type: <span class="mime-type">image/png</span>)</span>
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Template:Essay
# H1 : Template:Essay
# First Paragraph :
#  <p>This template adds the page to <a href="/wiki/Category:Wikipedia_essays" title="Category:Wikipedia essays">Category:Wikipedia essays</a> or to <a href="/wiki/Category:User_essays" title="Category:User essays">Category:User essays</a>, depending on <a href="/wiki/Wikipedia:Namespace" title="Wikipedia:Namespace">namespace</a>.
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Essays
# H1 : Wikipedia:Essays
# First Paragraph :
#  <p class="mw-empty-elt">
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:NOTESSAY
# H1 : Wikipedia:What Wikipedia is not
# First Paragraph :
#  <p>Wikipedia is a <a href="/wiki/Wikipedia:Wikipedia_is_free_content" title="Wikipedia:Wikipedia is free content">free</a> online <a href="/wiki/Encyclopedia" title="Encyclopedia">encyclopedia</a>. The amount of information on Wikipedia is practically unlimited, but Wikipedia does not aim to contain all knowledge. What to exclude is determined by an <a class="extiw" href="https://meta.wikimedia.org/wiki/The_Wikipedia_Community" title="meta:The Wikipedia Community">online community</a> committed to building a high-quality encyclopedia. These exclusions are summarized as <strong>things that Wikipedia is <em>not</em></strong>.
# </p>
# Something went wrong !!!!!!!!!!!!!!
# ---------------------------------------------------------
# /wiki/Wikipedia:Not_(disambiguation)
# H1 : Wikipedia:Not (disambiguation)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 27>()
#      24                 pages.add(newUrl)
#      25                 getLinksss(newUrl)
# ---> 27 getLinksss("")
#
# Input In [7], in getLinksss(pageUrl)
#      23 print("---------------------------------------------------------\n"+newUrl)
#      24 pages.add(newUrl)
# ---> 25 getLinksss(newUrl)
#
# Input In [7], in getLinksss(pageUrl)
#      23 print("---------------------------------------------------------\n"+newUrl)
#      24 pages.add(newUrl)
# ---> 25 getLinksss(newUrl)
#
#     [... skipping similar frames: getLinksss at line 25 (53 times)]
#
# Input In [7], in getLinksss(pageUrl)
#      23 print("---------------------------------------------------------\n"+newUrl)
#      24 pages.add(newUrl)
# ---> 25 getLinksss(newUrl)
#
# Input In [7], in getLinksss(pageUrl)
#      12 try:
#      13     print("H1 :",bsObj.h1.get_text())
# ---> 14     print("First Paragraph :\n",bsObj.find(id='mw-content-text').findAll("p")[0])
#      15     print("Edit Link :",bsObj.find(id='ca-edit').find("a").attrs["href"])
#      16 except AttributeError:
#
# IndexError: list index out of range

# %% [markdown]
# # Crawling Across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()

random.seed(datetime.datetime.now())

#Retriving a list of all internal links found on a page
def getInternalLinks(bsObj,includeUrl):
    includeUrl = urlparse(includeUrl).scheme+"://"+urlparse(includeUrl).netloc
    internalLinks = []
    
    #find all links that begins with a "/"
    for link in bsObj.findAll('a',href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
                    
#Retriving a list of all external links found on a page
def getExternalLinks(bsObj,excludeUrl):
    externalLinks = []
    
    #find all the links that start with http that do not contain the current URL
    for link in bsObj.findAll('a',href=re.compile('^(http|www)((?!'+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks


def getRandomExternalLinks(startingPage):
    html = urlopen(startingPage)
    bsObj = BeautifulSoup(html,'lxml')
    externalLinks = getExternalLinks(bsObj,urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print("No External link are looking around the site for one")
        domain = urlparse(startingPage).scheme+"://"+urlparse(startingPage).netloc
        internalLinks = getInternalLinks(bsObj,domain)
        return getRandomExternalLinks(internalLinks[random.randint(0,len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0,len(externalLinks)-1)]
    
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLinks(startingSite)
    print("Random External Link is :"+externalLink)
    followExternalOnly(externalLink)
    

#collect a list of all External URLs found on the site

allExtLinks = set()
allIntLinks = set()

def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = urlparse(siteUrl).scheme+"://"+urlparse(siteUrl).netloc
    bsObj = BeautifulSoup(html,'lxml')
    internalLinks = getInternalLinks(bsObj,domain)
    externalLinks = getExternalLinks(bsObj,domain)
    
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
        
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)

allIntLinks.add('http://python.org')
getAllExternalLinks('http://python.org')
followExternalOnly('http://python.org')
# Out:
# https://docs.python.org
# https://pypi.org/
# https://psfmember.org/civicrm/contribute/transact?reset=1&id=2
# https://www.facebook.com/pythonlang?fref=ts
# https://twitter.com/ThePSF
# http://brochure.getpython.info/
# https://docs.python.org/3/license.html
# https://wiki.python.org/moin/BeginnersGuide
# https://devguide.python.org/
# https://docs.python.org/faq/
# http://wiki.python.org/moin/Languages
# http://python.org/dev/peps/
# https://wiki.python.org/moin/PythonBooks
# https://wiki.python.org/moin/
# http://planetpython.org/
# http://pyfound.blogspot.com/
# http://pycon.blogspot.com/
# https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event
# http://docs.python.org/3/tutorial/introduction.html#using-python-as-a-calculator
# https://blog.python.org
# https://pythoninsider.blogspot.com/2022/09/python-3110rc2-is-now-available.html
# https://pythoninsider.blogspot.com/2022/09/python-releases-3107-3914-3814-and-3714.html
# https://pythoninsider.blogspot.com/2022/08/python-3110rc1-is-now-available.html
# https://pythoninsider.blogspot.com/2022/08/python-3106-is-available.html
# https://pythoninsider.blogspot.com/2022/07/python-3110b5-is-now-available.html
# http://www.djangoproject.com/
# http://www.pylonsproject.org/
# http://bottlepy.org
# http://tornadoweb.org
# http://flask.pocoo.org/
# http://www.web2py.com/
# http://wiki.python.org/moin/TkInter
# https://wiki.gnome.org/Projects/PyGObject
# http://www.riverbankcomputing.co.uk/software/pyqt/intro
# https://wiki.qt.io/PySide
# https://kivy.org/
# http://www.wxpython.org/
# http://www.scipy.org
# http://pandas.pydata.org/
# http://ipython.org
# http://buildbot.net/
# http://trac.edgewall.org/
# http://roundup.sourceforge.net/
# http://www.ansible.com
# https://saltproject.io
# https://www.openstack.org
# https://xon.sh
# https://bugs.python.org/
# https://mail.python.org/mailman/listinfo/python-dev
# https://github.com/python/pythondotorg/issues
# https://status.python.org/
# https://docs.google.com/forms/d/e/1FAIpQLSfwWBGkzvkWDZrxW3up_M_B7qgt1IWZlx9KJ0ucLA5WJP1vfA/viewform
# https://www.python.org/psf/donations/matching-gifts/
# https://www.python.org/psf/press-release/
# https://python.org
# https://pypi.org
# https://us.pycon.org
# http://pyfound.blogspot.com/2022/07/distinguished-service-award-granted-to.html
# http://pyfound.blogspot.com/2022/07/announcing-python-software-foundation.html
# http://pyfound.blogspot.com/2022/07/board-election-results-for-2022.html
# http://pyfound.blogspot.com/2022/06/the-psf-board-election-is-open.html
# http://pyfound.blogspot.com/2022/06/annual-report-2021.html
# http://pyfound.blogspot.com/2022/06/pycon-us-successful-return-to-in-person.html
# http://pyfound.blogspot.com/2022/06/welcome-chloe-gerhardson-to-psf-staff.html
# http://pyfound.blogspot.com/2022/06/python-developers-survey-2021-python-is.html
# http://pyfound.blogspot.com/2022/06/psf-board-election-dates-for-2022.html
# http://pyfound.blogspot.com/2022/05/pycon-jp-association-awarded-psf.html
# https://libera.chat/
# https://libera.chat/guides/registration
# http://www.irchelp.org
# https://python.zulipchat.com/
# https://python.zulipchat.com/#narrow/stream/174027-general.2Fhelp
# https://wiki.python.org/moin/BeginnersGuide/Programmers
# https://wiki.python.org/moin/BeginnersGuide/NonProgrammers
# https://wiki.python.org/moin/BeginnersGuide/Download
# https://wiki.python.org/moin/BeginnersGuide/Examples
# http://docs.python.org
# https://pypi.python.org
# https://docs.python.org/license.html
# http://opensource.org/licenses/Python-2.0
# http://pypi.org
# http://wiki.python.org/moin/WebProgramming
# http://bottlepy.org/
# http://www.plone.org/
# https://www.django-cms.org/
# http://docs.python.org/library/markup
# http://docs.python.org/library/json.html
# http://docs.python.org/library/email
# http://docs.python.org/library/ftplib.html
# http://docs.python.org/2/library/imaplib.html
# http://docs.python.org/library/internet
# http://docs.python.org/howto/sockets.html
# https://pypi.org/project/requests/
# http://www.crummy.com/software/BeautifulSoup/
# https://pypi.org/project/feedparser/
# https://pypi.org/project/paramiko/
# http://twistedmatrix.com/
# http://wiki.python.org/moin/NumericAndScientific
# http://scipy.org/
# http://ipython.org/
# http://software-carpentry.org
# http://www.openbookproject.net/thinkcs/python/english2e/
# http://mcsp.wartburg.edu/zelle/python/
# http://pragprog.com/book/gwpy2/practical-programming
# http://kivy.org/
# http://www.pyside.org/
# http://www.pygtk.org/
# http://sourceforge.net/projects/pywin32/
# http://www.scons.org/
# http://buildbot.sourceforge.net/
# http://gump.apache.org/
# http://www.edgewall.com/trac/
# https://www.odoo.com/
# http://www.tryton.org/
# http://youtube.com
# http://www.ilm.com
# http://google.com
# http://www.journyx.com
# http://www.ironport.com
# http://www.eve-online.com/
# http://www.ccpgames.com/
# http://HomeGain.com
# http://www.eztrip.com
# http://www.realestateagent.com
# http://www.volico.com/
# http://www.gdmag.com/
# http://games.slashdot.org/games/05/10/27/059220.shtml?tid=206&tid=11
# http://wiki.python.org/moin/BeginnersGuide/NonProgrammers
# http://wiki.python.org/moin/BeginnersGuide/Download
# http://wiki.python.org/moin/IntegratedDevelopmentEnvironments
# http://wiki.python.org/moin/PythonEditors
# http://wiki.python.org/moin/IntroductoryBooks
# http://wiki.python.org/moin/BeginnersGuide/Examples
# http://wiki.python.org/moin/BeginnersGuide/Programmers
# http://docs.python.org/3/tutorial/
# http://docs.python.org/3/library/
# http://docs.python.org/3/reference/
# http://code.activestate.com/recipes/langs/python/
# http://pypi.python.org/pypi?%3Aaction=index
# http://www.google.com
# http://docs.python.org/3/faq/
# https://docs.python.org/3/tutorial/
# https://github.com/python/cpython
# https://docs.python.org/3/faq/index.html
# https://discuss.python.org/c/users/
# https://mail.python.org/mailman/listinfo/tutor
# https://stackoverflow.com
# https://stackoverflow.com/tags/python
# https://github.com/python/pythondotorg/issues/
# https://pypi.python.org/
# https://bugs.python.org
# https://devguide.python.org/docquality.html
# https://pythondotorg.readthedocs.io/index.html
# https://discuss.python.org
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 81>()
#      78             getAllExternalLinks(link)
#      80 allIntLinks.add('http://python.org')
# ---> 81 getAllExternalLinks('http://python.org')
#      82 followExternalOnly('http://python.org')
#
# Input In [13], in getAllExternalLinks(siteUrl)
#      76 if link not in allIntLinks:
#      77     allIntLinks.add(link)
# ---> 78     getAllExternalLinks(link)
#
# Input In [13], in getAllExternalLinks(siteUrl)
#      76 if link not in allIntLinks:
#      77     allIntLinks.add(link)
# ---> 78     getAllExternalLinks(link)
#
#     [... skipping similar frames: getAllExternalLinks at line 78 (8 times)]
#
# Input In [13], in getAllExternalLinks(siteUrl)
#      76 if link not in allIntLinks:
#      77     allIntLinks.add(link)
# ---> 78     getAllExternalLinks(link)
#
# Input In [13], in getAllExternalLinks(siteUrl)
#      64 html = urlopen(siteUrl)
#      65 domain = urlparse(siteUrl).scheme+"://"+urlparse(siteUrl).netloc
# ---> 66 bsObj = BeautifulSoup(html,'lxml')
#      67 internalLinks = getInternalLinks(bsObj,domain)
#      68 externalLinks = getExternalLinks(bsObj,domain)
#
# File ~/.local/lib/python3.8/site-packages/bs4/__init__.py:312, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     309 self.parse_only = parse_only
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
# --> 312     markup = markup.read()
#     313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#    (...)
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#
# File /usr/lib/python3.8/http/client.py:472, in HTTPResponse.read(self, amt)
#     470 else:
#     471     try:
# --> 472         s = self._safe_read(self.length)
#     473     except IncompleteRead:
#     474         self._close_conn()
#
# File /usr/lib/python3.8/http/client.py:613, in HTTPResponse._safe_read(self, amt)
#     606 def _safe_read(self, amt):
#     607     """Read the number of bytes requested.
#     608
#     609     This function should be used when <amt> bytes "should" be present for
#     610     reading. If the bytes are truly not available (due to EOF), then the
#     611     IncompleteRead exception can be used to detect the problem.
#     612     """
# --> 613     data = self.fp.read(amt)
#     614     if len(data) < amt:
#     615         raise IncompleteRead(data, amt-len(data))
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
